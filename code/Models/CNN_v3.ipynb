# %%
# !pip install kaggle

# !kaggle datasets download -d landlord/handwriting-recognition

# !unzip handwriting-recognition.zip
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.14)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.4)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.7)
# Dataset URL: https://www.kaggle.com/datasets/landlord/handwriting-recognition
# License(s): CC0-1.0
# User cancelled operation
# Archive:  handwriting-recognition.zip
# replace test_v2/test/TEST_0001.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import torch
import tensorflow as tf
import os
import cv2
import imghdr
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelBinarizer
from itertools import chain
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
# If this cell fails you need to change the runtime of your colab notebook to GPU
# Go to Runtime -> Change Runtime Type and select GPU
assert torch.cuda.is_available(), "GPU is not enabled"

# use gpu if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# **Proves Codi 2**

# %%
import pandas as pd
import numpy as np
import keras
import keras.layers as L
import keras.models as M
import tensorflow as tf
from PIL import Image
import os
import matplotlib.pyplot as plt
import cv2
from keras.utils import Sequence
import tensorflow as tf
from tensorflow.keras import layers as L
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers.legacy import SGD as LegacySGD  # Use this if you prefer the legacy optimizer
from tensorflow.keras.layers import Layer

# %%
train = pd.read_csv('written_name_train_v2.csv')
validation = pd.read_csv('written_name_validation_v2.csv')
#rain_img_dir = 'train_v2/train'
#test_img_dir = 'validation_v2/validation'
#train.head(6), test.head(6)

# %%
train.dropna(inplace=True)

# %%
train.head()
# Out:
#           FILENAME   IDENTITY
# 0  TRAIN_00001.jpg  BALTHAZAR
# 1  TRAIN_00002.jpg      SIMON
# 2  TRAIN_00003.jpg      BENES
# 3  TRAIN_00004.jpg    LA LOVE
# 4  TRAIN_00005.jpg     DAPHNE

# %%
train['Length']=train['IDENTITY'].apply(lambda x : len(str(x)))
train=train[train['Length']<=21]
train['IDENTITY']=train['IDENTITY'].str.upper()
train[train['Length']==max(train['Length'])]
# Out:
#                 FILENAME               IDENTITY  Length
# 10278    TRAIN_10279.jpg  DOSSANTOS LASCONCELOS      21
# 108567  TRAIN_108568.jpg  O ZUARRDI EREBEVITRAC      21
# 156500  TRAIN_156501.jpg  ANDRIANNARISOA--DEGHI      21
# 160575  TRAIN_160576.jpg  LOUISIANE - EVANGELIN      21
# 174121  TRAIN_174122.jpg  GU ILLOSSOO - OARRIBA      21
# 212583  TRAIN_212584.jpg  DE MALEZIEUX DU HAMEL      21
# 220135  TRAIN_220136.jpg  COSTREL DE CORAINVILL      21
# 229529  TRAIN_229530.jpg  ROUSSEAV -- CHAUDIERE      21
# 230011  TRAIN_230012.jpg  BEKNARD DE LAVERNETTE      21
# 308769  TRAIN_308770.jpg  DATE NAISSANCE CLASSE      21
# 325215  TRAIN_325216.jpg  BEHARY - LAUL - SIRDE      21

# %%
train=train.sample(frac=0.8,random_state=42)
validation=validation.sample(frac=0.1)

# %%
characters=set()
train['IDENTITY']=train['IDENTITY'].apply(lambda x: str(x))
for i in train['IDENTITY'].values:
    for j in i :
        if j not in characters :
            characters.add(j)
characters=sorted(characters)

# %%
print(len(characters))
# Out:
# 30

# %%
# 2 Dictionaries  :   Turn all ur characters to num and vice versa
char_to_label = {char:label for label,char in enumerate(characters)}
label_to_char = {label:char for label,char in enumerate(characters)}

# %%
path_train= 'train_v2/train'
path_validation= 'validation_v2/validation'

# %%
# Data Generator
class DataGenerator(Sequence):
    def __init__(self,dataframe,path,char_map,batch_size=128,img_size=(256,64),
                 downsample_factor=4,max_length=22,shuffle=True):
        self.dataframe=dataframe
        self.path=path
        self.char_map=char_map
        self.batch_size=batch_size
        self.width=img_size[0]
        self.height=img_size[1]
        self.downsample_factor=downsample_factor
        self.max_length=max_length
        self.shuffle=shuffle
        self.indices = np.arange(len(dataframe))
        self.on_epoch_end()

    def __len__(self):
        return len(self.dataframe)//self.batch_size

    def __getitem__(self,idx):
        curr_batch_idx=self.indices[idx*self.batch_size:(idx+1)*self.batch_size]
        batch_images=np.ones((self.batch_size,self.width,self.height,1),dtype=np.float32)
        batch_labels=np.ones((self.batch_size,self.max_length),dtype=np.float32)
        input_length=np.ones((self.batch_size,1),dtype=np.float32)*(self.width//self.downsample_factor-2)
        label_length=np.zeros((self.batch_size,1),dtype=np.int64)
        for i,idx in enumerate(curr_batch_idx):
            img_path=self.dataframe['FILENAME'].values[idx]
            img=cv2.imread(self.path+'/'+img_path)
            img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            img=cv2.resize(img,(self.width,self.height))
            img=(img/255).astype(np.float32)
            img=img.T
            img=np.expand_dims(img,axis=-1)
            text=self.dataframe['IDENTITY'].values[idx]
            text=str(text)
            label=[]
            for j in text:
                if j in self.char_map :
                    label.append(self.char_map[j])
                else:
                    label.append(100)
            label.extend([100]*(22-len(label)))
            batch_images[i]=img
            batch_labels[i]=label
            label_length[i]=len(label)
        batch_inputs= {
                'input_data':batch_images,
                'input_label':batch_labels,
                'input_length':input_length,
                'label_length':label_length

            }
        return batch_inputs,np.zeros((self.batch_size),dtype=np.float32)
    def on_epoch_end(self):
        if self.shuffle == True :
            np.random.shuffle(self.indices)

# %%
train_generator=DataGenerator(train,path_train,char_to_label)
validation_generator=DataGenerator(validation,path_validation,char_to_label)

# %%
# Making CTC Function
class CTCLayer(L.Layer):
    def __init__(self, name=None):
        super().__init__(name=name)
        self.loss_fn = keras.backend.ctc_batch_cost

    def call(self, y_true, y_pred, input_length, label_length):
        # Compute the training-time loss value and add it
        # to the layer using `self.add_loss()`.
        loss = self.loss_fn(y_true, y_pred, input_length, label_length)
        self.add_loss(loss)

        # On test time, just return the computed loss
        return loss

# %%
def make_model():
    inp = L.Input(shape=(256, 64, 1), dtype=np.float32, name='input_data')
    labels = L.Input(shape=[22], dtype=np.float32, name='input_label')
    input_length = L.Input(shape=[1], dtype=np.int64, name='input_length')
    label_length = L.Input(shape=[1], dtype=np.int64, name='label_length')

    x = L.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(inp)
    x = L.MaxPooling2D(pool_size=(2, 2))(x)
    x = L.Dropout(0.3)(x)
    x = L.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(x)
    x = L.MaxPooling2D(pool_size=(2, 2))(x)
    x = L.Dropout(0.3)(x)
    new_shape = ((256 // 4), (64 // 4) * 128)
    x = L.Reshape(new_shape)(x)
    x = L.Dense(64, activation='relu')(x)
    x = L.Dropout(0.2)(x)
    x = L.Bidirectional(L.LSTM(128, return_sequences=True, dropout=0.2))(x)
    x = L.Bidirectional(L.LSTM(64, return_sequences=True, dropout=0.25))(x)
    x = L.Dense(len(characters) + 1, activation='softmax', kernel_initializer='he_normal', name='Dense_output')(x)
    output = CTCLayer(name='outputs')(labels, x, input_length, label_length)

    model = Model(inputs=[inp, labels, input_length, label_length], outputs=output)

    sgd = SGD(learning_rate=0.002, momentum=0.9, nesterov=True, clipnorm=5)
    # Alternatively, use the legacy SGD optimizer if needed
    # sgd = LegacySGD(learning_rate=0.002, decay=1e-6, momentum=0.9, nesterov=True, clipnorm=5)

    model.compile(optimizer=sgd,metrics=['accuracy'])

    return model

# %%
model=make_model()
model.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_data (InputLayer)     [(None, 256, 64, 1)]         0         []
#
#  conv2d_14 (Conv2D)          (None, 256, 64, 64)          640       ['input_data[0][0]']
#
#  max_pooling2d_14 (MaxPooli  (None, 128, 32, 64)          0         ['conv2d_14[0][0]']
#  ng2D)
#
#  dropout_21 (Dropout)        (None, 128, 32, 64)          0         ['max_pooling2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 128, 32, 128)         73856     ['dropout_21[0][0]']
#
#  max_pooling2d_15 (MaxPooli  (None, 64, 16, 128)          0         ['conv2d_15[0][0]']
#  ng2D)
#
#  dropout_22 (Dropout)        (None, 64, 16, 128)          0         ['max_pooling2d_15[0][0]']
#
#  reshape_7 (Reshape)         (None, 64, 2048)             0         ['dropout_22[0][0]']
#
#  dense_7 (Dense)             (None, 64, 64)               131136    ['reshape_7[0][0]']
#
#  dropout_23 (Dropout)        (None, 64, 64)               0         ['dense_7[0][0]']
#
#  bidirectional_14 (Bidirect  (None, 64, 256)              197632    ['dropout_23[0][0]']
#  ional)
#
#  bidirectional_15 (Bidirect  (None, 64, 128)              164352    ['bidirectional_14[0][0]']
#  ional)
#
#  input_label (InputLayer)    [(None, 22)]                 0         []
#
#  Dense_output (Dense)        (None, 64, 31)               3999      ['bidirectional_15[0][0]']
#
#  input_length (InputLayer)   [(None, 1)]                  0         []
#
#  label_length (InputLayer)   [(None, 1)]                  0         []
#
#  outputs (CTCLayer)          (None, 1)                    0         ['input_label[0][0]',
#                                                                      'Dense_output[0][0]',
#                                                                      'input_length[0][0]',
#                                                                      'label_length[0][0]']
#
# ==================================================================================================
# Total params: 571615 (2.18 MB)
# Trainable params: 571615 (2.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Add early stopping
es = keras.callbacks.EarlyStopping(monitor='val_loss',
                                   patience=5,
                                   restore_best_weights=True)

# Train the model
if 'prediction_model_ocr.h5' not in os.listdir('./'):
    history = model.fit(train_generator,steps_per_epoch=1000,validation_data=validation_generator,
                        epochs=8)
#history = model.fit(train_generator, epochs=10, batch_size=32, validation_data = validation_generator,  verbose=1)
# Out:
# Epoch 1/8
# 1000/1000 [==============================] - 258s 249ms/step - loss: 20.9084 - accuracy: 0.0000e+00 - val_loss: 19.5952 - val_accuracy: 0.0000e+00
# Epoch 2/8
# 1000/1000 [==============================] - 238s 238ms/step - loss: 18.3119 - accuracy: 0.0000e+00 - val_loss: 17.2421 - val_accuracy: 0.0000e+00
# Epoch 3/8
# 1000/1000 [==============================] - 238s 237ms/step - loss: 15.4534 - accuracy: 0.0000e+00 - val_loss: 11.9612 - val_accuracy: 0.0000e+00
# Epoch 4/8
# 1000/1000 [==============================] - 236s 236ms/step - loss: 10.3644 - accuracy: 0.0000e+00 - val_loss: 7.3272 - val_accuracy: 0.0000e+00
# Epoch 5/8
# 1000/1000 [==============================] - 236s 236ms/step - loss: 7.2494 - accuracy: 0.0040 - val_loss: 4.9496 - val_accuracy: 0.0532
# Epoch 6/8
# 1000/1000 [==============================] - 236s 236ms/step - loss: 5.5464 - accuracy: 0.0339 - val_loss: 3.8378 - val_accuracy: 0.1621
# Epoch 7/8
# 1000/1000 [==============================] - 236s 235ms/step - loss: 4.5583 - accuracy: 0.0964 - val_loss: 3.2494 - val_accuracy: 0.2720
# Epoch 8/8
# 1000/1000 [==============================] - 236s 236ms/step - loss: 3.9379 - accuracy: 0.1668 - val_loss: 2.7628 - val_accuracy: 0.3784

# %%
prediction_model = keras.models.Model(model.get_layer(name='input_data').input,
                                        model.get_layer(name='Dense_output').output)
prediction_model.summary()
# Out:
# Model: "model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_data (InputLayer)     [(None, 256, 64, 1)]      0
#
#  conv2d_14 (Conv2D)          (None, 256, 64, 64)       640
#
#  max_pooling2d_14 (MaxPooli  (None, 128, 32, 64)       0
#  ng2D)
#
#  dropout_21 (Dropout)        (None, 128, 32, 64)       0
#
#  conv2d_15 (Conv2D)          (None, 128, 32, 128)      73856
#
#  max_pooling2d_15 (MaxPooli  (None, 64, 16, 128)       0
#  ng2D)
#
#  dropout_22 (Dropout)        (None, 64, 16, 128)       0
#
#  reshape_7 (Reshape)         (None, 64, 2048)          0
#
#  dense_7 (Dense)             (None, 64, 64)            131136
#
#  dropout_23 (Dropout)        (None, 64, 64)            0
#
#  bidirectional_14 (Bidirect  (None, 64, 256)           197632
#  ional)
#
#  bidirectional_15 (Bidirect  (None, 64, 128)           164352
#  ional)
#
#  Dense_output (Dense)        (None, 64, 31)            3999
#
# =================================================================
# Total params: 571615 (2.18 MB)
# Trainable params: 571615 (2.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
if 'prediction_model_ocr.h5' not in os.listdir('./'):
    prediction_model.save('prediction_model_ocr.h5')
    prediction_model=M.load_model('prediction_model_ocr.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
label_to_char[100]=''

# %%
# A utility to decode the output of the network
def decode_batch_predictions(pred):
    pred = pred[:, :-2]
    input_len = np.ones(pred.shape[0])*pred.shape[1]

    # Use greedy search. For complex tasks, you can use beam search
    results = keras.backend.ctc_decode(pred,
                                        input_length=input_len,
                                        greedy=True)[0][0]

    # Iterate over the results and get back the text
    output_text = []
    for res in results.numpy():
        outstr = ''
        for c in res:
            if c < len(characters) and c >=0:
                outstr += label_to_char[c]
        output_text.append(outstr)

    # return final text results
    return output_text

# %%
for p, (inp_value, _) in enumerate(validation_generator):
    bs = inp_value['input_data'].shape[0]
    X_data = inp_value['input_data']
    labels = inp_value['input_label']
    plt.imshow(X_data[0])
    preds = prediction_model.predict(X_data)
    pred_texts = decode_batch_predictions(preds)


    orig_texts = []
    for label in labels:
        text = ''.join([label_to_char[int(x)] for x in label])
        orig_texts.append(text)
    for i in range(bs):
        print(f'Ground truth: {orig_texts[i]} \t Predicted: {pred_texts[i]}')
    break
# Out:
# 4/4 [==============================] - 1s 13ms/step
# Ground truth: ERRANDONEA 	 Predicted: ERANDONEA
# Ground truth: NOA 	 Predicted: NOAY
# Ground truth: GUERY 	 Predicted: GUEAY
# Ground truth: SALOME 	 Predicted: SALOME
# Ground truth: JEANNE 	 Predicted: JEANNE
# Ground truth: KEWAOILL 	 Predicted: KENAOIL
# Ground truth: LEIOP 	 Predicted: GRIOY
# Ground truth: TITOUAN 	 Predicted: TOUAN
# Ground truth: HAILYS 	 Predicted: MAILYS
# Ground truth: ANGELIQUE 	 Predicted: ANGELIAUE
# Ground truth: JULIE 	 Predicted: JULIE
# Ground truth: JULIE 	 Predicted: JULIE
# Ground truth: CASSUTTI 	 Predicted: CASSUTTI
# Ground truth: WILLIAM 	 Predicted: MILLIAN
# Ground truth: AMARINE 	 Predicted: AMARINE
# Ground truth: GUENAULT 	 Predicted: GUENAUIT
# Ground truth: JADE 	 Predicted: SOE
# Ground truth: ALUGWO 	 Predicted: ALUGNO
# Ground truth: CASSANDRE 	 Predicted: CASSANDRE
# Ground truth: LEMONY 	 Predicted: LEMONY
# Ground truth: JANIYAR 	 Predicted: ANIYAA
# Ground truth: KASSANDRA 	 Predicted: KASSANDRA
# Ground truth: DADGUILLOT 	 Predicted: DADDUILLOT
# Ground truth: MAJDA 	 Predicted: MASDA
# Ground truth: ALBISSER 	 Predicted: ALBISSER
# Ground truth: ARMET 	 Predicted: AMET
# Ground truth: VERE 	 Predicted: NERE
# Ground truth: GABRIEL 	 Predicted: GABRIEL
# Ground truth: COLINE 	 Predicted: COLINE
# Ground truth: MATTEO 	 Predicted: MATTEO
# Ground truth: BAPTISTE 	 Predicted: BAPTISTE
# Ground truth: GUEBLE 	 Predicted: GUEBLE
# Ground truth: HEBTING 	 Predicted: MERTINE
# Ground truth: DUPAS 	 Predicted: DUPAS
# Ground truth: LUCAS 	 Predicted: LUCAS
# Ground truth: ROBIN 	 Predicted: RORIN
# Ground truth: BERNEX 	 Predicted: BERNER
# Ground truth: DEPAQUY 	 Predicted: DEPABUY
# Ground truth: TRAIFFORT 	 Predicted: TRAIFFORT
# Ground truth: YUKSEL 	 Predicted: YURSEL
# Ground truth: BOUSQUET 	 Predicted: BOUSQUET
# Ground truth: HUGO 	 Predicted: HUGO
# Ground truth: VALLEE 	 Predicted: VALLEE
# Ground truth: BOUAMRANE 	 Predicted: BOURMBANE
# Ground truth: MARIE 	 Predicted: MARIE
# Ground truth: VANDENEMEN 	 Predicted: VANDENEMEN
# Ground truth: ALAN 	 Predicted: ALAA
# Ground truth: FEBVRE 	 Predicted: FEBVRE
# Ground truth: KALI 	 Predicted: KALT
# Ground truth: ENZO 	 Predicted: ENZO
# Ground truth: BELLINGER 	 Predicted: BELLINGER
# Ground truth: MANUEL 	 Predicted: MANUEL
# Ground truth: BASTIEN 	 Predicted: BASTIEN
# Ground truth: CESBRON 	 Predicted: CESBRON
# Ground truth: MOHINA 	 Predicted: MOHINA
# Ground truth: LOU 	 Predicted: LOU
# Ground truth: LAGORCE 	 Predicted: LAGORCE
# Ground truth: TOURE 	 Predicted: TOUIE
# Ground truth: LISA 	 Predicted: LISA
# Ground truth: BONNIN 	 Predicted: BONNEN
# Ground truth: ANSEL 	 Predicted: ANSEL
# Ground truth: ANGIBAUD 	 Predicted: ANGIBAUD
# Ground truth: EMIR 	 Predicted: EMIR
# Ground truth: BASTIEN 	 Predicted: BUAR
# Ground truth: THOMAS 	 Predicted: THOMAS
# Ground truth: AUTOCUS 	 Predicted: AUTOGUS
# Ground truth: ROUCHDI 	 Predicted: ROUCHOI
# Ground truth: NICOLAS 	 Predicted: NICOLAE
# Ground truth: JONQUET 	 Predicted: SONOUET
# Ground truth: LEANNA 	 Predicted: LEANNA
# Ground truth: LEBGHIL 	 Predicted: LEBGHIC
# Ground truth: COME 	 Predicted: COME
# Ground truth: LOE 	 Predicted: COE
# Ground truth: DIANE 	 Predicted: DIANE
# Ground truth: LEOPOLD 	 Predicted: LEOPOLA
# Ground truth: MARCHAND 	 Predicted: MARCHANO
# Ground truth: RENAUD 	 Predicted: RENAUO
# Ground truth: EVANO 	 Predicted: EVANO
# Ground truth: MONTET 	 Predicted: MONTET
# Ground truth: PAYRE 	 Predicted: PAYRE
# Ground truth: BESSALAH 	 Predicted: BESSALAH
# Ground truth: MARINE 	 Predicted: MARINE
# Ground truth: BERTRAND 	 Predicted: BERTRAND
# Ground truth: GABRIEL 	 Predicted: GABRIEL
# Ground truth: CHURANT 	 Predicted: CAURANT
# Ground truth: ANTON 	 Predicted: ANTON
# Ground truth: CABIROL 	 Predicted: CABIROL
# Ground truth: HARROU 	 Predicted: MARROU
# Ground truth: BOUALI 	 Predicted: BOUALI
# Ground truth: ANTOINE 	 Predicted: ANTOINE
# Ground truth: SIMON 	 Predicted: SIMON
# Ground truth: CAUX 	 Predicted: CAUX
# Ground truth: IWAN 	 Predicted: THAN
# Ground truth: ARTHUR 	 Predicted: ARTHUR
# Ground truth: THEO 	 Predicted: THEO
# Ground truth: DAMIEN 	 Predicted: DOMISA
# Ground truth: LIAM 	 Predicted: LIAM
# Ground truth: ZASOM 	 Predicted: SASOA
# Ground truth: VALENTIN 	 Predicted: VALENTIN
# Ground truth: MAELYNE 	 Predicted: MAELYNE
# Ground truth: ANIS 	 Predicted: ANIS
# Ground truth: ANTOINE 	 Predicted: ANTOINE
# Ground truth: TAMRI 	 Predicted: TAMRS
# Ground truth: LAFFARGUE 	 Predicted: LAFFARGUE
# Ground truth: ALEXANDRE 	 Predicted: ALEXANDRE
# Ground truth: ANQUEZ 	 Predicted: ANQUES
# Ground truth: ALEYNA 	 Predicted: ALEXNA
# Ground truth: NENE 	 Predicted: NENE
# Ground truth: MANON 	 Predicted: MANON
# Ground truth: GAILLARD 	 Predicted: GAILLARD
# Ground truth: CARLA 	 Predicted: CALA
# Ground truth: SIMON 	 Predicted: SIMON
# Ground truth: CAMILLE 	 Predicted: CAMILLE
# Ground truth: CLAIRE 	 Predicted: CLAIRE
# Ground truth: TERFAS 	 Predicted: TERFAS
# Ground truth: ROMAIN 	 Predicted: ROMAIN
# Ground truth: VIAL 	 Predicted: VIAL
# Ground truth: GROS 	 Predicted: GROS
# Ground truth: DUVINDASILVA 	 Predicted: DUVINDASILUR
# Ground truth: JADE 	 Predicted: JABE
# Ground truth: PRAGASSAME 	 Predicted: PREGASSAME
# Ground truth: SENOUSSI 	 Predicted: SENOUSAT
# Ground truth: GEOFFRIAU 	 Predicted: GEOFFRIAU
# Ground truth: LISA 	 Predicted: LISA
# Ground truth: SENAL 	 Predicted: SENAL
# Ground truth: LOUBNA 	 Predicted: LOUDNA
# Ground truth: KAMIL 	 Predicted: KAMIL
# Ground truth: PELLETIER-BARRERI 	 Predicted: PELLETIER-BARRERI

# %%
def compare_word_pairs(list1, list2):
    if len(list1) != len(list2):
        raise ValueError("Las listas deben tener la misma longitud")

    total_pairs = len(list1)
    same_word_count = 0
    same_letter_count = 0
    total_letters = 0

    for word1, word2 in zip(list1, list2):
        if word1 == word2:
            same_word_count += 1

        # Comparar letras
        if len(word1) == len(word2):
            min_length = min(len(word1), len(word2))
            total_letters += min_length
            same_letter_count += sum(1 for a, b in zip(word1, word2) if a == b)

    word_percentage = (same_word_count / total_pairs) * 100
    letter_percentage = (same_letter_count / total_letters) * 100

    return word_percentage, letter_percentage

# %%
print(len(orig_texts))
print(len(pred_texts))
word_percentage, letter_percentage = compare_word_pairs(orig_texts, pred_texts)

print(f"Porcentaje de palabras iguales: {word_percentage:.2f}%")
print(f"Porcentaje de letras iguales: {letter_percentage:.2f}%")
# Out:
# 128
# 128
# Porcentaje de palabras iguales: 60.16%
# Porcentaje de letras iguales: 92.68%

# %%
batch_images=np.ones((128,256,64,1),dtype=np.float32)
img=cv2.imread('test_v2/test/TEST_34083.jpg')
img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img=cv2.resize(img,(256,64))
img=(img/255).astype(np.float32)
img=img.T
img=np.expand_dims(img,axis=-1)
batch_images[0]=img
x=prediction_model.predict(batch_images)
pred_texts = decode_batch_predictions(x)
pred_texts = pred_texts[0]
im=cv2.imread('test_v2/test/TEST_34083.jpg')
plt.imshow(img)
plt.imshow(im)
print('Predicted Text:',pred_texts)
# Out:
# 4/4 [==============================] - 0s 14ms/step
# Predicted Text: ARABI
