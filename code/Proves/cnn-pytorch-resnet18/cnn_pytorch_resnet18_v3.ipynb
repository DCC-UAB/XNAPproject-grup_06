# %% [markdown]
# # CNN model using Pytorch

# %% [markdown]
# ## Import libraries

# %%
from __future__ import print_function
from __future__ import division
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import cv2
import torchvision
from torchvision import datasets, models, transforms
from torch.utils.data import Subset, DataLoader
from torch.utils.data import Dataset

from PIL import Image
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import time
import os
import copy
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %matplotlib inline
# Out:
# PyTorch Version:  2.3.0+cu121
# Torchvision Version:  0.18.0+cu121

# %% [markdown]
# ## Load the Data

# %%
# !pip install kaggle
# !kaggle datasets download -d guare13/handwritten-letters-recognition
# !unzip handwritten-letters-recognition.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: valid_letters/letter_3363.png
#   inflating: valid_letters/letter_33630.png
#   inflating: valid_letters/letter_33631.png
#   inflating: valid_letters/letter_33632.png
#   inflating: valid_letters/letter_33633.png
#   inflating: valid_letters/letter_33634.png
#   inflating: valid_letters/letter_33635.png
#   inflating: valid_letters/letter_33636.png
#   inflating: valid_letters/letter_33637.png
#   inflating: valid_letters/letter_33638.png
#   inflating: valid_letters/letter_33639.png
#   inflating: valid_letters/letter_3364.png
#   inflating: valid_letters/letter_33640.png
#   inflating: valid_letters/letter_33641.png
#   inflating: valid_letters/letter_33642.png
#   inflating: valid_letters/letter_33643.png
#   inflating: valid_letters/letter_33644.png
#   inflating: valid_letters/letter_33645.png
#   inflating: valid_letters/letter_33646.png
#   inflating: valid_letters/letter_33648.png
#   inflating: valid_letters/letter_33649.png
#   inflating: valid_letters/letter_3365.png
#   inflating: valid_letters/letter_33650.png
#   inflating: valid_letters/letter_33653.png
#   inflating: valid_letters/letter_33654.png
#   inflating: valid_letters/letter_33655.png
#   inflating: valid_letters/letter_33657.png
#   inflating: valid_letters/letter_33658.png
#   inflating: valid_letters/letter_33659.png
#   inflating: valid_letters/letter_3366.png
#   inflating: valid_letters/letter_33660.png
#   inflating: valid_letters/letter_33661.png
#   inflating: valid_letters/letter_33669.png
#   inflating: valid_letters/letter_3367.png
#   inflating: valid_letters/letter_33671.png
#   inflating: valid_letters/letter_33675.png
#   inflating: valid_letters/letter_33678.png
#   inflating: valid_letters/letter_33679.png
#   inflating: valid_letters/letter_3368.png
#   inflating: valid_letters/letter_33681.png
#   inflating: valid_letters/letter_33688.png
#   inflating: valid_letters/letter_3369.png
#   inflating: valid_letters/letter_33691.png
#   inflating: valid_letters/letter_33695.png
#   inflating: valid_letters/letter_33696.png
#   inflating: valid_letters/letter_33697.png
#   inflating: valid_letters/letter_33698.png
#   inflating: valid_letters/letter_33699.png
#   inflating: valid_letters/letter_337.png
#   inflating: valid_letters/letter_3370.png
#   inflating: valid_letters/letter_33700.png
#   inflating: valid_letters/letter_33701.png
#   inflating: valid_letters/letter_33702.png
#   inflating: valid_letters/letter_33703.png
#   inflating: valid_letters/letter_33704.png
#   inflating: valid_letters/letter_33705.png
#   inflating: valid_letters/letter_33707.png
#   inflating: valid_letters/letter_33708.png
#   inflating: valid_letters/letter_33709.png
#   inflating: valid_letters/letter_3371.png
#   inflating: valid_letters/letter_33711.png
#   inflating: valid_letters/letter_33712.png
#   inflating: valid_letters/letter_33715.png
#   inflating: valid_letters/letter_33718.png
#   inflating: valid_letters/letter_33719.png
#   inflating: valid_letters/letter_3372.png
#   inflating: valid_letters/letter_33720.png
#   inflating: valid_letters/letter_33721.png
#   inflating: valid_letters/letter_33722.png
#   inflating: valid_letters/letter_33723.png
#   inflating: valid_letters/letter_33724.png
#   inflating: valid_letters/letter_33725.png
#   inflating: valid_letters/letter_3373.png
#   inflating: valid_letters/letter_33733.png
#   inflating: valid_letters/letter_33734.png
#   inflating: valid_letters/letter_33735.png
#   inflating: valid_letters/letter_33736.png
#   inflating: valid_letters/letter_33737.png
#   inflating: valid_letters/letter_33738.png
#   inflating: valid_letters/letter_3374.png
#   inflating: valid_letters/letter_33741.png
#   inflating: valid_letters/letter_33742.png
#   inflating: valid_letters/letter_33743.png
#   inflating: valid_letters/letter_33744.png
#   inflating: valid_letters/letter_33745.png
#   inflating: valid_letters/letter_33747.png
#   inflating: valid_letters/letter_3375.png
#   inflating: valid_letters/letter_33750.png
#   inflating: valid_letters/letter_33751.png
#   inflating: valid_letters/letter_33752.png
#   inflating: valid_letters/letter_33753.png
#   inflating: valid_letters/letter_33755.png
#   inflating: valid_letters/letter_33756.png
#   inflating: valid_letters/letter_33757.png
#   inflating: valid_letters/letter_33758.png
#   inflating: valid_letters/letter_33759.png
#   inflating: valid_letters/letter_33760.png
#   inflating: valid_letters/letter_33761.png
#   inflating: valid_letters/letter_33762.png
#   inflating: valid_letters/letter_33763.png
#   inflating: valid_letters/letter_33765.png
#   inflating: valid_letters/letter_33766.png
#   inflating: valid_letters/letter_33767.png
#   inflating: valid_letters/letter_33768.png
#   inflating: valid_letters/letter_33769.png
#   inflating: valid_letters/letter_33770.png
#   inflating: valid_letters/letter_33771.png
#   inflating: valid_letters/letter_33772.png
#   inflating: valid_letters/letter_33773.png
#   inflating: valid_letters/letter_33774.png
#   inflating: valid_letters/letter_33775.png
#   inflating: valid_letters/letter_33777.png
#   inflating: valid_letters/letter_33779.png
#   inflating: valid_letters/letter_33780.png
#   inflating: valid_letters/letter_33787.png
#   inflating: valid_letters/letter_3379.png
#   inflating: valid_letters/letter_33796.png
#   inflating: valid_letters/letter_338.png
#   inflating: valid_letters/letter_33800.png
#   inflating: valid_letters/letter_33801.png
#   inflating: valid_letters/letter_3381.png
#   inflating: valid_letters/letter_33817.png
#   inflating: valid_letters/letter_33820.png
#   inflating: valid_letters/letter_33821.png
#   inflating: valid_letters/letter_33824.png
#   inflating: valid_letters/letter_33826.png
#   inflating: valid_letters/letter_33827.png
#   inflating: valid_letters/letter_33829.png
#   inflating: valid_letters/letter_3383.png
#   inflating: valid_letters/letter_33830.png
#   inflating: valid_letters/letter_33831.png
#   inflating: valid_letters/letter_33832.png
#   inflating: valid_letters/letter_33833.png
#   inflating: valid_letters/letter_33836.png
#   inflating: valid_letters/letter_33838.png
#   inflating: valid_letters/letter_33839.png
#   inflating: valid_letters/letter_33840.png
#   inflating: valid_letters/letter_33841.png
#   inflating: valid_letters/letter_33842.png
#   inflating: valid_letters/letter_33843.png
#   inflating: valid_letters/letter_33844.png
#   inflating: valid_letters/letter_33845.png
#   inflating: valid_letters/letter_33848.png
#   inflating: valid_letters/letter_33849.png
#   inflating: valid_letters/letter_33853.png
#   inflating: valid_letters/letter_33854.png
#   inflating: valid_letters/letter_33855.png
#   inflating: valid_letters/letter_33856.png
#   inflating: valid_letters/letter_33857.png
#   inflating: valid_letters/letter_33859.png
#   inflating: valid_letters/letter_33860.png
#   inflating: valid_letters/letter_33861.png
#   inflating: valid_letters/letter_33862.png
#   inflating: valid_letters/letter_33866.png
#   inflating: valid_letters/letter_33867.png
#   inflating: valid_letters/letter_33868.png
#   inflating: valid_letters/letter_33869.png
#   inflating: valid_letters/letter_33870.png
#   inflating: valid_letters/letter_33871.png
#   inflating: valid_letters/letter_33872.png
#   inflating: valid_letters/letter_33873.png
#   inflating: valid_letters/letter_33874.png
#   inflating: valid_letters/letter_33888.png
#   inflating: valid_letters/letter_33891.png
#   inflating: valid_letters/letter_33892.png
#   inflating: valid_letters/letter_33895.png
#   inflating: valid_letters/letter_33896.png
#   inflating: valid_letters/letter_33897.png
#   inflating: valid_letters/letter_33898.png
#   inflating: valid_letters/letter_339.png
#   inflating: valid_letters/letter_33900.png
#   inflating: valid_letters/letter_33901.png
#   inflating: valid_letters/letter_33906.png
#   inflating: valid_letters/letter_33907.png
#   inflating: valid_letters/letter_33908.png
#   inflating: valid_letters/letter_33909.png
#   inflating: valid_letters/letter_33918.png
#   inflating: valid_letters/letter_3393.png
#   inflating: valid_letters/letter_33930.png
#   inflating: valid_letters/letter_33931.png
#   inflating: valid_letters/letter_33933.png
#   inflating: valid_letters/letter_33934.png
#   inflating: valid_letters/letter_33936.png
#   inflating: valid_letters/letter_33937.png
#   inflating: valid_letters/letter_33939.png
#   inflating: valid_letters/letter_33940.png
#   inflating: valid_letters/letter_33941.png
#   inflating: valid_letters/letter_33942.png
#   inflating: valid_letters/letter_33943.png
#   inflating: valid_letters/letter_33948.png
#   inflating: valid_letters/letter_33949.png
#   inflating: valid_letters/letter_33956.png
#   inflating: valid_letters/letter_33957.png
#   inflating: valid_letters/letter_33958.png
#   inflating: valid_letters/letter_33959.png
#   inflating: valid_letters/letter_33960.png
#   inflating: valid_letters/letter_33961.png
#   inflating: valid_letters/letter_33962.png
#   inflating: valid_letters/letter_33963.png
#   inflating: valid_letters/letter_33966.png
#   inflating: valid_letters/letter_33967.png
#   inflating: valid_letters/letter_33968.png
#   inflating: valid_letters/letter_33969.png
#   inflating: valid_letters/letter_33970.png
#   inflating: valid_letters/letter_33971.png
#   inflating: valid_letters/letter_33972.png
#   inflating: valid_letters/letter_33973.png
#   inflating: valid_letters/letter_33975.png
#   inflating: valid_letters/letter_33976.png
#   inflating: valid_letters/letter_33977.png
#   inflating: valid_letters/letter_33978.png
#   inflating: valid_letters/letter_33980.png
#   inflating: valid_letters/letter_33981.png
#   inflating: valid_letters/letter_33982.png
#   inflating: valid_letters/letter_33983.png
#   inflating: valid_letters/letter_33984.png
#   inflating: valid_letters/letter_33985.png
#   inflating: valid_letters/letter_33986.png
#   inflating: valid_letters/letter_33987.png
#   inflating: valid_letters/letter_33988.png
#   inflating: valid_letters/letter_33989.png
#   inflating: valid_letters/letter_33990.png
#   inflating: valid_letters/letter_33991.png
#   inflating: valid_letters/letter_33992.png
#   inflating: valid_letters/letter_33994.png
#   inflating: valid_letters/letter_33995.png
#   inflating: valid_letters/letter_33996.png
#   inflating: valid_letters/letter_340.png
#   inflating: valid_letters/letter_34001.png
#   inflating: valid_letters/letter_34002.png
#   inflating: valid_letters/letter_34003.png
#   inflating: valid_letters/letter_34004.png
#   inflating: valid_letters/letter_34005.png
#   inflating: valid_letters/letter_34008.png
#   inflating: valid_letters/letter_34023.png
#   inflating: valid_letters/letter_34024.png
#   inflating: valid_letters/letter_34025.png
#   inflating: valid_letters/letter_34027.png
#   inflating: valid_letters/letter_34028.png
#   inflating: valid_letters/letter_3403.png
#   inflating: valid_letters/letter_34034.png
#   inflating: valid_letters/letter_34035.png
#   inflating: valid_letters/letter_34036.png
#   inflating: valid_letters/letter_3404.png
#   inflating: valid_letters/letter_34044.png
#   inflating: valid_letters/letter_34045.png
#   inflating: valid_letters/letter_34047.png
#   inflating: valid_letters/letter_34048.png
#   inflating: valid_letters/letter_34052.png
#   inflating: valid_letters/letter_34055.png
#   inflating: valid_letters/letter_34058.png
#   inflating: valid_letters/letter_34059.png
#   inflating: valid_letters/letter_34060.png
#   inflating: valid_letters/letter_34062.png
#   inflating: valid_letters/letter_34063.png
#   inflating: valid_letters/letter_34064.png
#   inflating: valid_letters/letter_34065.png
#   inflating: valid_letters/letter_34067.png
#   inflating: valid_letters/letter_34071.png
#   inflating: valid_letters/letter_34073.png
#   inflating: valid_letters/letter_34074.png
#   inflating: valid_letters/letter_34075.png
#   inflating: valid_letters/letter_34076.png
#   inflating: valid_letters/letter_34077.png
#   inflating: valid_letters/letter_34079.png
#   inflating: valid_letters/letter_34081.png
#   inflating: valid_letters/letter_34082.png
#   inflating: valid_letters/letter_34083.png
#   inflating: valid_letters/letter_34084.png
#   inflating: valid_letters/letter_34085.png
#   inflating: valid_letters/letter_34086.png
#   inflating: valid_letters/letter_34087.png
#   inflating: valid_letters/letter_34088.png
#   inflating: valid_letters/letter_34089.png
#   inflating: valid_letters/letter_3409.png
#   inflating: valid_letters/letter_34090.png
#   inflating: valid_letters/letter_34092.png
#   inflating: valid_letters/letter_34093.png
#   inflating: valid_letters/letter_34094.png
#   inflating: valid_letters/letter_34098.png
#   inflating: valid_letters/letter_3410.png
#   inflating: valid_letters/letter_34103.png
#   inflating: valid_letters/letter_34104.png
#   inflating: valid_letters/letter_34107.png
#   inflating: valid_letters/letter_34108.png
#   inflating: valid_letters/letter_34112.png
#   inflating: valid_letters/letter_34113.png
#   inflating: valid_letters/letter_34114.png
#   inflating: valid_letters/letter_34115.png
#   inflating: valid_letters/letter_34117.png
#   inflating: valid_letters/letter_34124.png
#   inflating: valid_letters/letter_34125.png
#   inflating: valid_letters/letter_34126.png
#   inflating: valid_letters/letter_34127.png
#   inflating: valid_letters/letter_34128.png
#   inflating: valid_letters/letter_34129.png
#   inflating: valid_letters/letter_3413.png
#   inflating: valid_letters/letter_34132.png
#   inflating: valid_letters/letter_34134.png
#   inflating: valid_letters/letter_34136.png
#   inflating: valid_letters/letter_34137.png
#   inflating: valid_letters/letter_34139.png
#   inflating: valid_letters/letter_34140.png
#   inflating: valid_letters/letter_34141.png
#   inflating: valid_letters/letter_34143.png
#   inflating: valid_letters/letter_34144.png
#   inflating: valid_letters/letter_34145.png
#   inflating: valid_letters/letter_34146.png
#   inflating: valid_letters/letter_34154.png
#   inflating: valid_letters/letter_34155.png
#   inflating: valid_letters/letter_34156.png
#   inflating: valid_letters/letter_34157.png
#   inflating: valid_letters/letter_34158.png
#   inflating: valid_letters/letter_3416.png
#   inflating: valid_letters/letter_34160.png
#   inflating: valid_letters/letter_34161.png
#   inflating: valid_letters/letter_34162.png
#   inflating: valid_letters/letter_34163.png
#   inflating: valid_letters/letter_34164.png
#   inflating: valid_letters/letter_34166.png
#   inflating: valid_letters/letter_34169.png
#   inflating: valid_letters/letter_3417.png
#   inflating: valid_letters/letter_34170.png
#   inflating: valid_letters/letter_34171.png
#   inflating: valid_letters/letter_34172.png
#   inflating: valid_letters/letter_34173.png
#   inflating: valid_letters/letter_34176.png
#   inflating: valid_letters/letter_34177.png
#   inflating: valid_letters/letter_34178.png
#   inflating: valid_letters/letter_34180.png
#   inflating: valid_letters/letter_34181.png
#   inflating: valid_letters/letter_34182.png
#   inflating: valid_letters/letter_34183.png
#   inflating: valid_letters/letter_34184.png
#   inflating: valid_letters/letter_34185.png
#   inflating: valid_letters/letter_34186.png
#   inflating: valid_letters/letter_34187.png
#   inflating: valid_letters/letter_34191.png
#   inflating: valid_letters/letter_34198.png
#   inflating: valid_letters/letter_34201.png
#   inflating: valid_letters/letter_34203.png
#   inflating: valid_letters/letter_34204.png
#   inflating: valid_letters/letter_34205.png
#   inflating: valid_letters/letter_34206.png
#   inflating: valid_letters/letter_34207.png
#   inflating: valid_letters/letter_34208.png
#   inflating: valid_letters/letter_34213.png
#   inflating: valid_letters/letter_34215.png
#   inflating: valid_letters/letter_34216.png
#   inflating: valid_letters/letter_34217.png
#   inflating: valid_letters/letter_34218.png
#   inflating: valid_letters/letter_34219.png
#   inflating: valid_letters/letter_34220.png
#   inflating: valid_letters/letter_34221.png
#   inflating: valid_letters/letter_34222.png
#   inflating: valid_letters/letter_34223.png
#   inflating: valid_letters/letter_34224.png
#   inflating: valid_letters/letter_34225.png
#   inflating: valid_letters/letter_34226.png
#   inflating: valid_letters/letter_34227.png
#   inflating: valid_letters/letter_34230.png
#   inflating: valid_letters/letter_34232.png
#   inflating: valid_letters/letter_34238.png
#   inflating: valid_letters/letter_34239.png
#   inflating: valid_letters/letter_34240.png
#   inflating: valid_letters/letter_34241.png
#   inflating: valid_letters/letter_34242.png
#   inflating: valid_letters/letter_34243.png
#   inflating: valid_letters/letter_34244.png
#   inflating: valid_letters/letter_34245.png
#   inflating: valid_letters/letter_34246.png
#   inflating: valid_letters/letter_34248.png
#   inflating: valid_letters/letter_34249.png
#   inflating: valid_letters/letter_34250.png
#   inflating: valid_letters/letter_34251.png
#   inflating: valid_letters/letter_34252.png
#   inflating: valid_letters/letter_34253.png
#   inflating: valid_letters/letter_34254.png
#   inflating: valid_letters/letter_34255.png
#   inflating: valid_letters/letter_34256.png
#   inflating: valid_letters/letter_34258.png
#   inflating: valid_letters/letter_34260.png
#   inflating: valid_letters/letter_34261.png
#   inflating: valid_letters/letter_34262.png
#   inflating: valid_letters/letter_34263.png
#   inflating: valid_letters/letter_34264.png
#   inflating: valid_letters/letter_34265.png
#   inflating: valid_letters/letter_34266.png
#   inflating: valid_letters/letter_34267.png
#   inflating: valid_letters/letter_34268.png
#   inflating: valid_letters/letter_34269.png
#   inflating: valid_letters/letter_34270.png
#   inflating: valid_letters/letter_34272.png
#   inflating: valid_letters/letter_34273.png
#   inflating: valid_letters/letter_34274.png
#   inflating: valid_letters/letter_34275.png
#   inflating: valid_letters/letter_34276.png
#   inflating: valid_letters/letter_34277.png
#   inflating: valid_letters/letter_34278.png
#   inflating: valid_letters/letter_34279.png
#   inflating: valid_letters/letter_34280.png
#   inflating: valid_letters/letter_34281.png
#   inflating: valid_letters/letter_34282.png
#   inflating: valid_letters/letter_34283.png
#   inflating: valid_letters/letter_34284.png
#   inflating: valid_letters/letter_34285.png
#   inflating: valid_letters/letter_34287.png
#   inflating: valid_letters/letter_34289.png
#   inflating: valid_letters/letter_34290.png
#   inflating: valid_letters/letter_34291.png
#   inflating: valid_letters/letter_34292.png
#   inflating: valid_letters/letter_34293.png
#   inflating: valid_letters/letter_34294.png
#   inflating: valid_letters/letter_34295.png
#   inflating: valid_letters/letter_34296.png
#   inflating: valid_letters/letter_34297.png
#   inflating: valid_letters/letter_34299.png
#   inflating: valid_letters/letter_34302.png
#   inflating: valid_letters/letter_34306.png
#   inflating: valid_letters/letter_34310.png
#   inflating: valid_letters/letter_34312.png
#   inflating: valid_letters/letter_34313.png
#   inflating: valid_letters/letter_34314.png
#   inflating: valid_letters/letter_34315.png
#   inflating: valid_letters/letter_34316.png
#   inflating: valid_letters/letter_34318.png
#   inflating: valid_letters/letter_34320.png
#   inflating: valid_letters/letter_34324.png
#   inflating: valid_letters/letter_34326.png
#   inflating: valid_letters/letter_34327.png
#   inflating: valid_letters/letter_34328.png
#   inflating: valid_letters/letter_34329.png
#   inflating: valid_letters/letter_3433.png
#   inflating: valid_letters/letter_34330.png
#   inflating: valid_letters/letter_34331.png
#   inflating: valid_letters/letter_34332.png
#   inflating: valid_letters/letter_34346.png
#   inflating: valid_letters/letter_34351.png
#   inflating: valid_letters/letter_34352.png
#   inflating: valid_letters/letter_34358.png
#   inflating: valid_letters/letter_34364.png
#   inflating: valid_letters/letter_34365.png
#   inflating: valid_letters/letter_34366.png
#   inflating: valid_letters/letter_34367.png
#   inflating: valid_letters/letter_34368.png
#   inflating: valid_letters/letter_34369.png
#   inflating: valid_letters/letter_3437.png
#   inflating: valid_letters/letter_34373.png
#   inflating: valid_letters/letter_34374.png
#   inflating: valid_letters/letter_34376.png
#   inflating: valid_letters/letter_34377.png
#   inflating: valid_letters/letter_34378.png
#   inflating: valid_letters/letter_34379.png
#   inflating: valid_letters/letter_3438.png
#   inflating: valid_letters/letter_34385.png
#   inflating: valid_letters/letter_3439.png
#   inflating: valid_letters/letter_34392.png
#   inflating: valid_letters/letter_34399.png
#   inflating: valid_letters/letter_34400.png
#   inflating: valid_letters/letter_34401.png
#   inflating: valid_letters/letter_34403.png
#   inflating: valid_letters/letter_34404.png
#   inflating: valid_letters/letter_34405.png
#   inflating: valid_letters/letter_34406.png
#   inflating: valid_letters/letter_34407.png
#   inflating: valid_letters/letter_34409.png
#   inflating: valid_letters/letter_3441.png
#   inflating: valid_letters/letter_34410.png
#   inflating: valid_letters/letter_34411.png
#   inflating: valid_letters/letter_34412.png
#   inflating: valid_letters/letter_34418.png
#   inflating: valid_letters/letter_3442.png
#   inflating: valid_letters/letter_34421.png
#   inflating: valid_letters/letter_34422.png
#   inflating: valid_letters/letter_34425.png
#   inflating: valid_letters/letter_34426.png
#   inflating: valid_letters/letter_34427.png
#   inflating: valid_letters/letter_34428.png
#   inflating: valid_letters/letter_34429.png
#   inflating: valid_letters/letter_3443.png
#   inflating: valid_letters/letter_34430.png
#   inflating: valid_letters/letter_34431.png
#   inflating: valid_letters/letter_34432.png
#   inflating: valid_letters/letter_34433.png
#   inflating: valid_letters/letter_34434.png
#   inflating: valid_letters/letter_34435.png
#   inflating: valid_letters/letter_34436.png
#   inflating: valid_letters/letter_34437.png
#   inflating: valid_letters/letter_34438.png
#   inflating: valid_letters/letter_34439.png
#   inflating: valid_letters/letter_3444.png
#   inflating: valid_letters/letter_34440.png
#   inflating: valid_letters/letter_34441.png
#   inflating: valid_letters/letter_34442.png
#   inflating: valid_letters/letter_34443.png
#   inflating: valid_letters/letter_34445.png
#   inflating: valid_letters/letter_34446.png
#   inflating: valid_letters/letter_34447.png
#   inflating: valid_letters/letter_34448.png
#   inflating: valid_letters/letter_3445.png
#   inflating: valid_letters/letter_34450.png
#   inflating: valid_letters/letter_34454.png
#   inflating: valid_letters/letter_34455.png
#   inflating: valid_letters/letter_34457.png
#   inflating: valid_letters/letter_34459.png
#   inflating: valid_letters/letter_3446.png
#   inflating: valid_letters/letter_34460.png
#   inflating: valid_letters/letter_34461.png
#   inflating: valid_letters/letter_34462.png
#   inflating: valid_letters/letter_34463.png
#   inflating: valid_letters/letter_34464.png
#   inflating: valid_letters/letter_34466.png
#   inflating: valid_letters/letter_34467.png
#   inflating: valid_letters/letter_3447.png
#   inflating: valid_letters/letter_34473.png
#   inflating: valid_letters/letter_34474.png
#   inflating: valid_letters/letter_34475.png
#   inflating: valid_letters/letter_34476.png
#   inflating: valid_letters/letter_3448.png
#   inflating: valid_letters/letter_34487.png
#   inflating: valid_letters/letter_34489.png
#   inflating: valid_letters/letter_34490.png
#   inflating: valid_letters/letter_34492.png
#   inflating: valid_letters/letter_34493.png
#   inflating: valid_letters/letter_34494.png
#   inflating: valid_letters/letter_3450.png
#   inflating: valid_letters/letter_34501.png
#   inflating: valid_letters/letter_34502.png
#   inflating: valid_letters/letter_34503.png
#   inflating: valid_letters/letter_34504.png
#   inflating: valid_letters/letter_34505.png
#   inflating: valid_letters/letter_34506.png
#   inflating: valid_letters/letter_34507.png
#   inflating: valid_letters/letter_34508.png
#   inflating: valid_letters/letter_34509.png
#   inflating: valid_letters/letter_34510.png
#   inflating: valid_letters/letter_34511.png
#   inflating: valid_letters/letter_34512.png
#   inflating: valid_letters/letter_34513.png
#   inflating: valid_letters/letter_34514.png
#   inflating: valid_letters/letter_34515.png
#   inflating: valid_letters/letter_34516.png
#   inflating: valid_letters/letter_34517.png
#   inflating: valid_letters/letter_34518.png
#   inflating: valid_letters/letter_34519.png
#   inflating: valid_letters/letter_34520.png
#   inflating: valid_letters/letter_34521.png
#   inflating: valid_letters/letter_34522.png
#   inflating: valid_letters/letter_34526.png
#   inflating: valid_letters/letter_3453.png
#   inflating: valid_letters/letter_34535.png
#   inflating: valid_letters/letter_34536.png
#   inflating: valid_letters/letter_34538.png
#   inflating: valid_letters/letter_34541.png
#   inflating: valid_letters/letter_34542.png
#   inflating: valid_letters/letter_34543.png
#   inflating: valid_letters/letter_34545.png
#   inflating: valid_letters/letter_34546.png
#   inflating: valid_letters/letter_34548.png
#   inflating: valid_letters/letter_34549.png
#   inflating: valid_letters/letter_34556.png
#   inflating: valid_letters/letter_34559.png
#   inflating: valid_letters/letter_3456.png
#   inflating: valid_letters/letter_34569.png
#   inflating: valid_letters/letter_3457.png
#   inflating: valid_letters/letter_34570.png
#   inflating: valid_letters/letter_34571.png
#   inflating: valid_letters/letter_34572.png
#   inflating: valid_letters/letter_34573.png
#   inflating: valid_letters/letter_34574.png
#   inflating: valid_letters/letter_34579.png
#   inflating: valid_letters/letter_3458.png
#   inflating: valid_letters/letter_34583.png
#   inflating: valid_letters/letter_34584.png
#   inflating: valid_letters/letter_34586.png
#   inflating: valid_letters/letter_34587.png
#   inflating: valid_letters/letter_34588.png
#   inflating: valid_letters/letter_3459.png
#   inflating: valid_letters/letter_34590.png
#   inflating: valid_letters/letter_34594.png
#   inflating: valid_letters/letter_34595.png
#   inflating: valid_letters/letter_34596.png
#   inflating: valid_letters/letter_34597.png
#   inflating: valid_letters/letter_34598.png
#   inflating: valid_letters/letter_34599.png
#   inflating: valid_letters/letter_3460.png
#   inflating: valid_letters/letter_34600.png
#   inflating: valid_letters/letter_34601.png
#   inflating: valid_letters/letter_34603.png
#   inflating: valid_letters/letter_34604.png
#   inflating: valid_letters/letter_34605.png
#   inflating: valid_letters/letter_34606.png
#   inflating: valid_letters/letter_34607.png
#   inflating: valid_letters/letter_3461.png
#   inflating: valid_letters/letter_34610.png
#   inflating: valid_letters/letter_34611.png
#   inflating: valid_letters/letter_34612.png
#   inflating: valid_letters/letter_34613.png
#   inflating: valid_letters/letter_34615.png
#   inflating: valid_letters/letter_3462.png
#   inflating: valid_letters/letter_34624.png
#   inflating: valid_letters/letter_34633.png
#   inflating: valid_letters/letter_34634.png
#   inflating: valid_letters/letter_3464.png
#   inflating: valid_letters/letter_34642.png
#   inflating: valid_letters/letter_34643.png
#   inflating: valid_letters/letter_34644.png
#   inflating: valid_letters/letter_34645.png
#   inflating: valid_letters/letter_34646.png
#   inflating: valid_letters/letter_34647.png
#   inflating: valid_letters/letter_34648.png
#   inflating: valid_letters/letter_34650.png
#   inflating: valid_letters/letter_34651.png
#   inflating: valid_letters/letter_34652.png
#   inflating: valid_letters/letter_34653.png
#   inflating: valid_letters/letter_34654.png
#   inflating: valid_letters/letter_34655.png
#   inflating: valid_letters/letter_34658.png
#   inflating: valid_letters/letter_34660.png
#   inflating: valid_letters/letter_34661.png
#   inflating: valid_letters/letter_34662.png
#   inflating: valid_letters/letter_34663.png
#   inflating: valid_letters/letter_34667.png
#   inflating: valid_letters/letter_34669.png
#   inflating: valid_letters/letter_34670.png
#   inflating: valid_letters/letter_34671.png
#   inflating: valid_letters/letter_34672.png
#   inflating: valid_letters/letter_34673.png
#   inflating: valid_letters/letter_34674.png
#   inflating: valid_letters/letter_34675.png
#   inflating: valid_letters/letter_34676.png
#   inflating: valid_letters/letter_34677.png
#   inflating: valid_letters/letter_34679.png
#   inflating: valid_letters/letter_34681.png
#   inflating: valid_letters/letter_34682.png
#   inflating: valid_letters/letter_34687.png
#   inflating: valid_letters/letter_34689.png
#   inflating: valid_letters/letter_34695.png
#   inflating: valid_letters/letter_34697.png
#   inflating: valid_letters/letter_34702.png
#   inflating: valid_letters/letter_34704.png
#   inflating: valid_letters/letter_34705.png
#   inflating: valid_letters/letter_34706.png
#   inflating: valid_letters/letter_34707.png
#   inflating: valid_letters/letter_34708.png
#   inflating: valid_letters/letter_34709.png
#   inflating: valid_letters/letter_3471.png
#   inflating: valid_letters/letter_34710.png
#   inflating: valid_letters/letter_34711.png
#   inflating: valid_letters/letter_34712.png
#   inflating: valid_letters/letter_34713.png
#   inflating: valid_letters/letter_34714.png
#   inflating: valid_letters/letter_34715.png
#   inflating: valid_letters/letter_34716.png
#   inflating: valid_letters/letter_34717.png
#   inflating: valid_letters/letter_34718.png
#   inflating: valid_letters/letter_3472.png
#   inflating: valid_letters/letter_34721.png
#   inflating: valid_letters/letter_34724.png
#   inflating: valid_letters/letter_34725.png
#   inflating: valid_letters/letter_34727.png
#   inflating: valid_letters/letter_34728.png
#   inflating: valid_letters/letter_34729.png
#   inflating: valid_letters/letter_3473.png
#   inflating: valid_letters/letter_34730.png
#   inflating: valid_letters/letter_34731.png
#   inflating: valid_letters/letter_34732.png
#   inflating: valid_letters/letter_34733.png
#   inflating: valid_letters/letter_34734.png
#   inflating: valid_letters/letter_34735.png
#   inflating: valid_letters/letter_34736.png
#   inflating: valid_letters/letter_34737.png
#   inflating: valid_letters/letter_34738.png
#   inflating: valid_letters/letter_34739.png
#   inflating: valid_letters/letter_3474.png
#   inflating: valid_letters/letter_34740.png
#   inflating: valid_letters/letter_34741.png
#   inflating: valid_letters/letter_34742.png
#   inflating: valid_letters/letter_34743.png
#   inflating: valid_letters/letter_34744.png
#   inflating: valid_letters/letter_34745.png
#   inflating: valid_letters/letter_34747.png
#   inflating: valid_letters/letter_34751.png
#   inflating: valid_letters/letter_34752.png
#   inflating: valid_letters/letter_34753.png
#   inflating: valid_letters/letter_34755.png
#   inflating: valid_letters/letter_34758.png
#   inflating: valid_letters/letter_34759.png
#   inflating: valid_letters/letter_34760.png
#   inflating: valid_letters/letter_34762.png
#   inflating: valid_letters/letter_34763.png
#   inflating: valid_letters/letter_34764.png
#   inflating: valid_letters/letter_34765.png
#   inflating: valid_letters/letter_34766.png
#   inflating: valid_letters/letter_34767.png
#   inflating: valid_letters/letter_34768.png
#   inflating: valid_letters/letter_3477.png
#   inflating: valid_letters/letter_34770.png
#   inflating: valid_letters/letter_34771.png
#   inflating: valid_letters/letter_34772.png
#   inflating: valid_letters/letter_34781.png
#   inflating: valid_letters/letter_34782.png
#   inflating: valid_letters/letter_34783.png
#   inflating: valid_letters/letter_34784.png
#   inflating: valid_letters/letter_34785.png
#   inflating: valid_letters/letter_34786.png
#   inflating: valid_letters/letter_34787.png
#   inflating: valid_letters/letter_34790.png
#   inflating: valid_letters/letter_34793.png
#   inflating: valid_letters/letter_34794.png
#   inflating: valid_letters/letter_34795.png
#   inflating: valid_letters/letter_34807.png
#   inflating: valid_letters/letter_34808.png
#   inflating: valid_letters/letter_34809.png
#   inflating: valid_letters/letter_34810.png
#   inflating: valid_letters/letter_34811.png
#   inflating: valid_letters/letter_34812.png
#   inflating: valid_letters/letter_34813.png
#   inflating: valid_letters/letter_34814.png
#   inflating: valid_letters/letter_34815.png
#   inflating: valid_letters/letter_34816.png
#   inflating: valid_letters/letter_34817.png
#   inflating: valid_letters/letter_34818.png
#   inflating: valid_letters/letter_34819.png
#   inflating: valid_letters/letter_34820.png
#   inflating: valid_letters/letter_34822.png
#   inflating: valid_letters/letter_34824.png
#   inflating: valid_letters/letter_34826.png
#   inflating: valid_letters/letter_34828.png
#   inflating: valid_letters/letter_3483.png
#   inflating: valid_letters/letter_34831.png
#   inflating: valid_letters/letter_3484.png
#   inflating: valid_letters/letter_34840.png
#   inflating: valid_letters/letter_34842.png
#   inflating: valid_letters/letter_34844.png
#   inflating: valid_letters/letter_34845.png
#   inflating: valid_letters/letter_34846.png
#   inflating: valid_letters/letter_34848.png
#   inflating: valid_letters/letter_34850.png
#   inflating: valid_letters/letter_34852.png
#   inflating: valid_letters/letter_34853.png
#   inflating: valid_letters/letter_34854.png
#   inflating: valid_letters/letter_34856.png
#   inflating: valid_letters/letter_34857.png
#   inflating: valid_letters/letter_34859.png
#   inflating: valid_letters/letter_34860.png
#   inflating: valid_letters/letter_34861.png
#   inflating: valid_letters/letter_34862.png
#   inflating: valid_letters/letter_34863.png
#   inflating: valid_letters/letter_34864.png
#   inflating: valid_letters/letter_34866.png
#   inflating: valid_letters/letter_34868.png
#   inflating: valid_letters/letter_34869.png
#   inflating: valid_letters/letter_3487.png
#   inflating: valid_letters/letter_34871.png
#   inflating: valid_letters/letter_34872.png
#   inflating: valid_letters/letter_34873.png
#   inflating: valid_letters/letter_34875.png
#   inflating: valid_letters/letter_34876.png
#   inflating: valid_letters/letter_34877.png
#   inflating: valid_letters/letter_34879.png
#   inflating: valid_letters/letter_3488.png
#   inflating: valid_letters/letter_34890.png
#   inflating: valid_letters/letter_3490.png
#   inflating: valid_letters/letter_34901.png
#   inflating: valid_letters/letter_34902.png
#   inflating: valid_letters/letter_34903.png
#   inflating: valid_letters/letter_34904.png
#   inflating: valid_letters/letter_34905.png
#   inflating: valid_letters/letter_34906.png
#   inflating: valid_letters/letter_34907.png
#   inflating: valid_letters/letter_34909.png
#   inflating: valid_letters/letter_34910.png
#   inflating: valid_letters/letter_34911.png
#   inflating: valid_letters/letter_34914.png
#   inflating: valid_letters/letter_34919.png
#   inflating: valid_letters/letter_3492.png
#   inflating: valid_letters/letter_34921.png
#   inflating: valid_letters/letter_34922.png
#   inflating: valid_letters/letter_34924.png
#   inflating: valid_letters/letter_3493.png
#   inflating: valid_letters/letter_34931.png
#   inflating: valid_letters/letter_34935.png
#   inflating: valid_letters/letter_34936.png
#   inflating: valid_letters/letter_34937.png
#   inflating: valid_letters/letter_34938.png
#   inflating: valid_letters/letter_34939.png
#   inflating: valid_letters/letter_34940.png
#   inflating: valid_letters/letter_34941.png
#   inflating: valid_letters/letter_34943.png
#   inflating: valid_letters/letter_34944.png
#   inflating: valid_letters/letter_34945.png
#   inflating: valid_letters/letter_34946.png
#   inflating: valid_letters/letter_34947.png
#   inflating: valid_letters/letter_34948.png
#   inflating: valid_letters/letter_34951.png
#   inflating: valid_letters/letter_34952.png
#   inflating: valid_letters/letter_34956.png
#   inflating: valid_letters/letter_34958.png
#   inflating: valid_letters/letter_34959.png
#   inflating: valid_letters/letter_34961.png
#   inflating: valid_letters/letter_34966.png
#   inflating: valid_letters/letter_34968.png
#   inflating: valid_letters/letter_34969.png
#   inflating: valid_letters/letter_3497.png
#   inflating: valid_letters/letter_34970.png
#   inflating: valid_letters/letter_34977.png
#   inflating: valid_letters/letter_34978.png
#   inflating: valid_letters/letter_34979.png
#   inflating: valid_letters/letter_34980.png
#   inflating: valid_letters/letter_34981.png
#   inflating: valid_letters/letter_34987.png
#   inflating: valid_letters/letter_34990.png
#   inflating: valid_letters/letter_34991.png
#   inflating: valid_letters/letter_34993.png
#   inflating: valid_letters/letter_34995.png
#   inflating: valid_letters/letter_34996.png
#   inflating: valid_letters/letter_34997.png
#   inflating: valid_letters/letter_34998.png
#   inflating: valid_letters/letter_350.png
#   inflating: valid_letters/letter_35004.png
#   inflating: valid_letters/letter_35005.png
#   inflating: valid_letters/letter_35006.png
#   inflating: valid_letters/letter_35007.png
#   inflating: valid_letters/letter_35008.png
#   inflating: valid_letters/letter_35010.png
#   inflating: valid_letters/letter_35011.png
#   inflating: valid_letters/letter_35012.png
#   inflating: valid_letters/letter_35013.png
#   inflating: valid_letters/letter_35014.png
#   inflating: valid_letters/letter_35015.png
#   inflating: valid_letters/letter_35016.png
#   inflating: valid_letters/letter_35017.png
#   inflating: valid_letters/letter_35018.png
#   inflating: valid_letters/letter_35027.png
#   inflating: valid_letters/letter_35028.png
#   inflating: valid_letters/letter_35029.png
#   inflating: valid_letters/letter_3503.png
#   inflating: valid_letters/letter_35032.png
#   inflating: valid_letters/letter_35033.png
#   inflating: valid_letters/letter_35035.png
#   inflating: valid_letters/letter_3504.png
#   inflating: valid_letters/letter_35045.png
#   inflating: valid_letters/letter_35046.png
#   inflating: valid_letters/letter_35047.png
#   inflating: valid_letters/letter_3505.png
#   inflating: valid_letters/letter_35050.png
#   inflating: valid_letters/letter_35051.png
#   inflating: valid_letters/letter_35052.png
#   inflating: valid_letters/letter_35053.png
#   inflating: valid_letters/letter_35054.png
#   inflating: valid_letters/letter_35056.png
#   inflating: valid_letters/letter_35059.png
#   inflating: valid_letters/letter_3506.png
#   inflating: valid_letters/letter_35061.png
#   inflating: valid_letters/letter_35062.png
#   inflating: valid_letters/letter_35064.png
#   inflating: valid_letters/letter_35065.png
#   inflating: valid_letters/letter_35066.png
#   inflating: valid_letters/letter_35067.png
#   inflating: valid_letters/letter_35068.png
#   inflating: valid_letters/letter_35069.png
#   inflating: valid_letters/letter_3507.png
#   inflating: valid_letters/letter_35070.png
#   inflating: valid_letters/letter_35072.png
#   inflating: valid_letters/letter_35073.png
#   inflating: valid_letters/letter_35074.png
#   inflating: valid_letters/letter_35075.png
#   inflating: valid_letters/letter_35076.png
#   inflating: valid_letters/letter_35077.png
#   inflating: valid_letters/letter_35078.png
#   inflating: valid_letters/letter_35079.png
#   inflating: valid_letters/letter_3508.png
#   inflating: valid_letters/letter_35084.png
#   inflating: valid_letters/letter_3509.png
#   inflating: valid_letters/letter_351.png
#   inflating: valid_letters/letter_35100.png
#   inflating: valid_letters/letter_35101.png
#   inflating: valid_letters/letter_35104.png
#   inflating: valid_letters/letter_35107.png
#   inflating: valid_letters/letter_35108.png
#   inflating: valid_letters/letter_35109.png
#   inflating: valid_letters/letter_35110.png
#   inflating: valid_letters/letter_35112.png
#   inflating: valid_letters/letter_35113.png
#   inflating: valid_letters/letter_35116.png
#   inflating: valid_letters/letter_35117.png
#   inflating: valid_letters/letter_35118.png
#   inflating: valid_letters/letter_35119.png
#   inflating: valid_letters/letter_35120.png
#   inflating: valid_letters/letter_35122.png
#   inflating: valid_letters/letter_35124.png
#   inflating: valid_letters/letter_35125.png
#   inflating: valid_letters/letter_35126.png
#   inflating: valid_letters/letter_35127.png
#   inflating: valid_letters/letter_35128.png
#   inflating: valid_letters/letter_35129.png
#   inflating: valid_letters/letter_35131.png
#   inflating: valid_letters/letter_35132.png
#   inflating: valid_letters/letter_35133.png
#   inflating: valid_letters/letter_35135.png
#   inflating: valid_letters/letter_35136.png
#   inflating: valid_letters/letter_35137.png
#   inflating: valid_letters/letter_35138.png
#   inflating: valid_letters/letter_35142.png
#   inflating: valid_letters/letter_35146.png
#   inflating: valid_letters/letter_35147.png
#   inflating: valid_letters/letter_35148.png
#   inflating: valid_letters/letter_35149.png
#   inflating: valid_letters/letter_35150.png
#   inflating: valid_letters/letter_35151.png
#   inflating: valid_letters/letter_35153.png
#   inflating: valid_letters/letter_35154.png
#   inflating: valid_letters/letter_35155.png
#   inflating: valid_letters/letter_35156.png
#   inflating: valid_letters/letter_35157.png
#   inflating: valid_letters/letter_35163.png
#   inflating: valid_letters/letter_35164.png
#   inflating: valid_letters/letter_35166.png
#   inflating: valid_letters/letter_35169.png
#   inflating: valid_letters/letter_35176.png
#   inflating: valid_letters/letter_35177.png
#   inflating: valid_letters/letter_35180.png
#   inflating: valid_letters/letter_35181.png
#   inflating: valid_letters/letter_35182.png
#   inflating: valid_letters/letter_35183.png
#   inflating: valid_letters/letter_35184.png
#   inflating: valid_letters/letter_35185.png
#   inflating: valid_letters/letter_35186.png
#   inflating: valid_letters/letter_35187.png
#   inflating: valid_letters/letter_35188.png
#   inflating: valid_letters/letter_35189.png
#   inflating: valid_letters/letter_3519.png
#   inflating: valid_letters/letter_35190.png
#   inflating: valid_letters/letter_35191.png
#   inflating: valid_letters/letter_35193.png
#   inflating: valid_letters/letter_35194.png
#   inflating: valid_letters/letter_35195.png
#   inflating: valid_letters/letter_35196.png
#   inflating: valid_letters/letter_35197.png
#   inflating: valid_letters/letter_35198.png
#   inflating: valid_letters/letter_35199.png
#   inflating: valid_letters/letter_35200.png
#   inflating: valid_letters/letter_35201.png
#   inflating: valid_letters/letter_35202.png
#   inflating: valid_letters/letter_35203.png
#   inflating: valid_letters/letter_3521.png
#   inflating: valid_letters/letter_35212.png
#   inflating: valid_letters/letter_35217.png
#   inflating: valid_letters/letter_35218.png
#   inflating: valid_letters/letter_3522.png
#   inflating: valid_letters/letter_35223.png
#   inflating: valid_letters/letter_35224.png
#   inflating: valid_letters/letter_35226.png
#   inflating: valid_letters/letter_35227.png
#   inflating: valid_letters/letter_35228.png
#   inflating: valid_letters/letter_35230.png
#   inflating: valid_letters/letter_35231.png
#   inflating: valid_letters/letter_35232.png
#   inflating: valid_letters/letter_3527.png
#   inflating: valid_letters/letter_3529.png
#   inflating: valid_letters/letter_353.png
#   inflating: valid_letters/letter_3530.png
#   inflating: valid_letters/letter_3534.png
#   inflating: valid_letters/letter_3537.png
#   inflating: valid_letters/letter_3539.png
#   inflating: valid_letters/letter_354.png
#   inflating: valid_letters/letter_3540.png
#   inflating: valid_letters/letter_3541.png
#   inflating: valid_letters/letter_3543.png
#   inflating: valid_letters/letter_3544.png
#   inflating: valid_letters/letter_3545.png
#   inflating: valid_letters/letter_3553.png
#   inflating: valid_letters/letter_3555.png
#   inflating: valid_letters/letter_3557.png
#   inflating: valid_letters/letter_3559.png
#   inflating: valid_letters/letter_3569.png
#   inflating: valid_letters/letter_3571.png
#   inflating: valid_letters/letter_3572.png
#   inflating: valid_letters/letter_3573.png
#   inflating: valid_letters/letter_3574.png
#   inflating: valid_letters/letter_3575.png
#   inflating: valid_letters/letter_3576.png
#   inflating: valid_letters/letter_3577.png
#   inflating: valid_letters/letter_3578.png
#   inflating: valid_letters/letter_3581.png
#   inflating: valid_letters/letter_3582.png
#   inflating: valid_letters/letter_3608.png
#   inflating: valid_letters/letter_3609.png
#   inflating: valid_letters/letter_3611.png
#   inflating: valid_letters/letter_3615.png
#   inflating: valid_letters/letter_3616.png
#   inflating: valid_letters/letter_3617.png
#   inflating: valid_letters/letter_3618.png
#   inflating: valid_letters/letter_3619.png
#   inflating: valid_letters/letter_3620.png
#   inflating: valid_letters/letter_3630.png
#   inflating: valid_letters/letter_3632.png
#   inflating: valid_letters/letter_3633.png
#   inflating: valid_letters/letter_3634.png
#   inflating: valid_letters/letter_364.png
#   inflating: valid_letters/letter_3643.png
#   inflating: valid_letters/letter_3645.png
#   inflating: valid_letters/letter_3646.png
#   inflating: valid_letters/letter_3647.png
#   inflating: valid_letters/letter_3649.png
#   inflating: valid_letters/letter_365.png
#   inflating: valid_letters/letter_3650.png
#   inflating: valid_letters/letter_366.png
#   inflating: valid_letters/letter_3663.png
#   inflating: valid_letters/letter_3664.png
#   inflating: valid_letters/letter_3665.png
#   inflating: valid_letters/letter_3666.png
#   inflating: valid_letters/letter_3667.png
#   inflating: valid_letters/letter_3668.png
#   inflating: valid_letters/letter_3669.png
#   inflating: valid_letters/letter_367.png
#   inflating: valid_letters/letter_3671.png
#   inflating: valid_letters/letter_3672.png
#   inflating: valid_letters/letter_3673.png
#   inflating: valid_letters/letter_3675.png
#   inflating: valid_letters/letter_3676.png
#   inflating: valid_letters/letter_3677.png
#   inflating: valid_letters/letter_3679.png
#   inflating: valid_letters/letter_368.png
#   inflating: valid_letters/letter_369.png
#   inflating: valid_letters/letter_3693.png
#   inflating: valid_letters/letter_3697.png
#   inflating: valid_letters/letter_3698.png
#   inflating: valid_letters/letter_3699.png
#   inflating: valid_letters/letter_370.png
#   inflating: valid_letters/letter_3703.png
#   inflating: valid_letters/letter_3706.png
#   inflating: valid_letters/letter_3710.png
#   inflating: valid_letters/letter_3713.png
#   inflating: valid_letters/letter_3714.png
#   inflating: valid_letters/letter_3715.png
#   inflating: valid_letters/letter_3716.png
#   inflating: valid_letters/letter_3717.png
#   inflating: valid_letters/letter_372.png
#   inflating: valid_letters/letter_3731.png
#   inflating: valid_letters/letter_3733.png
#   inflating: valid_letters/letter_3735.png
#   inflating: valid_letters/letter_3738.png
#   inflating: valid_letters/letter_3739.png
#   inflating: valid_letters/letter_374.png
# ...
#   inflating: valid_letters/letter_9406.png
#   inflating: valid_letters/letter_9407.png
#   inflating: valid_letters/letter_9408.png
#   inflating: valid_letters/letter_9409.png
#   inflating: valid_letters/letter_941.png
#   inflating: valid_letters/letter_9410.png
#   inflating: valid_letters/letter_9411.png
#   inflating: valid_letters/letter_9412.png
#   inflating: valid_letters/letter_9413.png
#   inflating: valid_letters/letter_9414.png
#   inflating: valid_letters/letter_9415.png
#   inflating: valid_letters/letter_9416.png
#   inflating: valid_letters/letter_9419.png
#   inflating: valid_letters/letter_9421.png
#   inflating: valid_letters/letter_9424.png
#   inflating: valid_letters/letter_9425.png
#   inflating: valid_letters/letter_9426.png
#   inflating: valid_letters/letter_9434.png
#   inflating: valid_letters/letter_9436.png
#   inflating: valid_letters/letter_9437.png
#   inflating: valid_letters/letter_9438.png
#   inflating: valid_letters/letter_944.png
#   inflating: valid_letters/letter_9440.png
#   inflating: valid_letters/letter_9441.png
#   inflating: valid_letters/letter_9442.png
#   inflating: valid_letters/letter_9443.png
#   inflating: valid_letters/letter_9446.png
#   inflating: valid_letters/letter_9448.png
#   inflating: valid_letters/letter_9449.png
#   inflating: valid_letters/letter_945.png
#   inflating: valid_letters/letter_9450.png
#   inflating: valid_letters/letter_9452.png
#   inflating: valid_letters/letter_9453.png
#   inflating: valid_letters/letter_9454.png
#   inflating: valid_letters/letter_9455.png
#   inflating: valid_letters/letter_9456.png
#   inflating: valid_letters/letter_9457.png
#   inflating: valid_letters/letter_9458.png
#   inflating: valid_letters/letter_9459.png
#   inflating: valid_letters/letter_946.png
#   inflating: valid_letters/letter_9460.png
#   inflating: valid_letters/letter_9462.png
#   inflating: valid_letters/letter_9463.png
#   inflating: valid_letters/letter_9474.png
#   inflating: valid_letters/letter_9476.png
#   inflating: valid_letters/letter_948.png
#   inflating: valid_letters/letter_9481.png
#   inflating: valid_letters/letter_9482.png
#   inflating: valid_letters/letter_9483.png
#   inflating: valid_letters/letter_9485.png
#   inflating: valid_letters/letter_9491.png
#   inflating: valid_letters/letter_9499.png
#   inflating: valid_letters/letter_950.png
#   inflating: valid_letters/letter_9500.png
#   inflating: valid_letters/letter_9501.png
#   inflating: valid_letters/letter_9502.png
#   inflating: valid_letters/letter_9503.png
#   inflating: valid_letters/letter_9504.png
#   inflating: valid_letters/letter_9505.png
#   inflating: valid_letters/letter_9506.png
#   inflating: valid_letters/letter_9507.png
#   inflating: valid_letters/letter_9508.png
#   inflating: valid_letters/letter_9509.png
#   inflating: valid_letters/letter_9510.png
#   inflating: valid_letters/letter_9511.png
#   inflating: valid_letters/letter_9512.png
#   inflating: valid_letters/letter_9514.png
#   inflating: valid_letters/letter_9516.png
#   inflating: valid_letters/letter_9517.png
#   inflating: valid_letters/letter_9518.png
#   inflating: valid_letters/letter_9519.png
#   inflating: valid_letters/letter_9520.png
#   inflating: valid_letters/letter_9521.png
#   inflating: valid_letters/letter_9523.png
#   inflating: valid_letters/letter_9524.png
#   inflating: valid_letters/letter_9527.png
#   inflating: valid_letters/letter_9528.png
#   inflating: valid_letters/letter_9529.png
#   inflating: valid_letters/letter_9530.png
#   inflating: valid_letters/letter_9537.png
#   inflating: valid_letters/letter_9538.png
#   inflating: valid_letters/letter_9539.png
#   inflating: valid_letters/letter_954.png
#   inflating: valid_letters/letter_9540.png
#   inflating: valid_letters/letter_9541.png
#   inflating: valid_letters/letter_9542.png
#   inflating: valid_letters/letter_9544.png
#   inflating: valid_letters/letter_9545.png
#   inflating: valid_letters/letter_9546.png
#   inflating: valid_letters/letter_9547.png
#   inflating: valid_letters/letter_9548.png
#   inflating: valid_letters/letter_955.png
#   inflating: valid_letters/letter_9551.png
#   inflating: valid_letters/letter_9560.png
#   inflating: valid_letters/letter_9561.png
#   inflating: valid_letters/letter_9564.png
#   inflating: valid_letters/letter_9571.png
#   inflating: valid_letters/letter_9572.png
#   inflating: valid_letters/letter_9573.png
#   inflating: valid_letters/letter_9574.png
#   inflating: valid_letters/letter_9575.png
#   inflating: valid_letters/letter_9576.png
#   inflating: valid_letters/letter_9580.png
#   inflating: valid_letters/letter_9582.png
#   inflating: valid_letters/letter_9587.png
#   inflating: valid_letters/letter_9591.png
#   inflating: valid_letters/letter_9597.png
#   inflating: valid_letters/letter_9598.png
#   inflating: valid_letters/letter_9599.png
#   inflating: valid_letters/letter_960.png
#   inflating: valid_letters/letter_9600.png
#   inflating: valid_letters/letter_9601.png
#   inflating: valid_letters/letter_9602.png
#   inflating: valid_letters/letter_9603.png
#   inflating: valid_letters/letter_9605.png
#   inflating: valid_letters/letter_9606.png
#   inflating: valid_letters/letter_9609.png
#   inflating: valid_letters/letter_9611.png
#   inflating: valid_letters/letter_9612.png
#   inflating: valid_letters/letter_9613.png
#   inflating: valid_letters/letter_9614.png
#   inflating: valid_letters/letter_9615.png
#   inflating: valid_letters/letter_9616.png
#   inflating: valid_letters/letter_9617.png
#   inflating: valid_letters/letter_9618.png
#   inflating: valid_letters/letter_9619.png
#   inflating: valid_letters/letter_962.png
#   inflating: valid_letters/letter_9621.png
#   inflating: valid_letters/letter_9623.png
#   inflating: valid_letters/letter_9624.png
#   inflating: valid_letters/letter_9625.png
#   inflating: valid_letters/letter_9626.png
#   inflating: valid_letters/letter_9627.png
#   inflating: valid_letters/letter_9632.png
#   inflating: valid_letters/letter_9634.png
#   inflating: valid_letters/letter_964.png
#   inflating: valid_letters/letter_9642.png
#   inflating: valid_letters/letter_9645.png
#   inflating: valid_letters/letter_9648.png
#   inflating: valid_letters/letter_9649.png
#   inflating: valid_letters/letter_9659.png
#   inflating: valid_letters/letter_9661.png
#   inflating: valid_letters/letter_9663.png
#   inflating: valid_letters/letter_9667.png
#   inflating: valid_letters/letter_9669.png
#   inflating: valid_letters/letter_9678.png
#   inflating: valid_letters/letter_968.png
#   inflating: valid_letters/letter_9680.png
#   inflating: valid_letters/letter_9681.png
#   inflating: valid_letters/letter_9684.png
#   inflating: valid_letters/letter_9688.png
#   inflating: valid_letters/letter_9689.png
#   inflating: valid_letters/letter_969.png
#   inflating: valid_letters/letter_9690.png
#   inflating: valid_letters/letter_9692.png
#   inflating: valid_letters/letter_9693.png
#   inflating: valid_letters/letter_9694.png
#   inflating: valid_letters/letter_9695.png
#   inflating: valid_letters/letter_9697.png
#   inflating: valid_letters/letter_9699.png
#   inflating: valid_letters/letter_970.png
#   inflating: valid_letters/letter_9707.png
#   inflating: valid_letters/letter_9713.png
#   inflating: valid_letters/letter_9714.png
#   inflating: valid_letters/letter_9715.png
#   inflating: valid_letters/letter_9716.png
#   inflating: valid_letters/letter_9718.png
#   inflating: valid_letters/letter_9719.png
#   inflating: valid_letters/letter_972.png
#   inflating: valid_letters/letter_9720.png
#   inflating: valid_letters/letter_9721.png
#   inflating: valid_letters/letter_9722.png
#   inflating: valid_letters/letter_9723.png
#   inflating: valid_letters/letter_9724.png
#   inflating: valid_letters/letter_9725.png
#   inflating: valid_letters/letter_9726.png
#   inflating: valid_letters/letter_9727.png
#   inflating: valid_letters/letter_973.png
#   inflating: valid_letters/letter_9737.png
#   inflating: valid_letters/letter_9738.png
#   inflating: valid_letters/letter_9739.png
#   inflating: valid_letters/letter_974.png
#   inflating: valid_letters/letter_9742.png
#   inflating: valid_letters/letter_9743.png
#   inflating: valid_letters/letter_9745.png
#   inflating: valid_letters/letter_9747.png
#   inflating: valid_letters/letter_9748.png
#   inflating: valid_letters/letter_9749.png
#   inflating: valid_letters/letter_9750.png
#   inflating: valid_letters/letter_9751.png
#   inflating: valid_letters/letter_9753.png
#   inflating: valid_letters/letter_9755.png
#   inflating: valid_letters/letter_9756.png
#   inflating: valid_letters/letter_9757.png
#   inflating: valid_letters/letter_9758.png
#   inflating: valid_letters/letter_9759.png
#   inflating: valid_letters/letter_976.png
#   inflating: valid_letters/letter_9760.png
#   inflating: valid_letters/letter_9762.png
#   inflating: valid_letters/letter_9763.png
#   inflating: valid_letters/letter_9766.png
#   inflating: valid_letters/letter_9767.png
#   inflating: valid_letters/letter_9768.png
#   inflating: valid_letters/letter_9769.png
#   inflating: valid_letters/letter_977.png
#   inflating: valid_letters/letter_9770.png
#   inflating: valid_letters/letter_9772.png
#   inflating: valid_letters/letter_9774.png
#   inflating: valid_letters/letter_9775.png
#   inflating: valid_letters/letter_9779.png
#   inflating: valid_letters/letter_978.png
#   inflating: valid_letters/letter_9780.png
#   inflating: valid_letters/letter_9781.png
#   inflating: valid_letters/letter_9782.png
#   inflating: valid_letters/letter_9783.png
#   inflating: valid_letters/letter_9784.png
#   inflating: valid_letters/letter_9785.png
#   inflating: valid_letters/letter_9786.png
#   inflating: valid_letters/letter_9787.png
#   inflating: valid_letters/letter_9788.png
#   inflating: valid_letters/letter_9789.png
#   inflating: valid_letters/letter_979.png
#   inflating: valid_letters/letter_9790.png
#   inflating: valid_letters/letter_9791.png
#   inflating: valid_letters/letter_9792.png
#   inflating: valid_letters/letter_9794.png
#   inflating: valid_letters/letter_9795.png
#   inflating: valid_letters/letter_9796.png
#   inflating: valid_letters/letter_9797.png
#   inflating: valid_letters/letter_9798.png
#   inflating: valid_letters/letter_9799.png
#   inflating: valid_letters/letter_980.png
#   inflating: valid_letters/letter_9800.png
#   inflating: valid_letters/letter_9801.png
#   inflating: valid_letters/letter_9802.png
#   inflating: valid_letters/letter_9803.png
#   inflating: valid_letters/letter_9804.png
#   inflating: valid_letters/letter_9805.png
#   inflating: valid_letters/letter_9806.png
#   inflating: valid_letters/letter_981.png
#   inflating: valid_letters/letter_9810.png
#   inflating: valid_letters/letter_9811.png
#   inflating: valid_letters/letter_9818.png
#   inflating: valid_letters/letter_9819.png
#   inflating: valid_letters/letter_982.png
#   inflating: valid_letters/letter_9820.png
#   inflating: valid_letters/letter_9822.png
#   inflating: valid_letters/letter_9823.png
#   inflating: valid_letters/letter_9828.png
#   inflating: valid_letters/letter_9829.png
#   inflating: valid_letters/letter_9831.png
#   inflating: valid_letters/letter_9833.png
#   inflating: valid_letters/letter_9834.png
#   inflating: valid_letters/letter_9835.png
#   inflating: valid_letters/letter_9836.png
#   inflating: valid_letters/letter_9837.png
#   inflating: valid_letters/letter_9838.png
#   inflating: valid_letters/letter_9839.png
#   inflating: valid_letters/letter_984.png
#   inflating: valid_letters/letter_9840.png
#   inflating: valid_letters/letter_9841.png
#   inflating: valid_letters/letter_9843.png
#   inflating: valid_letters/letter_9844.png
#   inflating: valid_letters/letter_9845.png
#   inflating: valid_letters/letter_9846.png
#   inflating: valid_letters/letter_9847.png
#   inflating: valid_letters/letter_9848.png
#   inflating: valid_letters/letter_9849.png
#   inflating: valid_letters/letter_985.png
#   inflating: valid_letters/letter_9851.png
#   inflating: valid_letters/letter_9853.png
#   inflating: valid_letters/letter_9854.png
#   inflating: valid_letters/letter_9855.png
#   inflating: valid_letters/letter_9856.png
#   inflating: valid_letters/letter_9857.png
#   inflating: valid_letters/letter_9858.png
#   inflating: valid_letters/letter_9859.png
#   inflating: valid_letters/letter_986.png
#   inflating: valid_letters/letter_9860.png
#   inflating: valid_letters/letter_9865.png
#   inflating: valid_letters/letter_9866.png
#   inflating: valid_letters/letter_9867.png
#   inflating: valid_letters/letter_9869.png
#   inflating: valid_letters/letter_987.png
#   inflating: valid_letters/letter_9871.png
#   inflating: valid_letters/letter_9872.png
#   inflating: valid_letters/letter_9873.png
#   inflating: valid_letters/letter_9874.png
#   inflating: valid_letters/letter_9875.png
#   inflating: valid_letters/letter_9876.png
#   inflating: valid_letters/letter_9877.png
#   inflating: valid_letters/letter_9884.png
#   inflating: valid_letters/letter_9885.png
#   inflating: valid_letters/letter_9886.png
#   inflating: valid_letters/letter_9887.png
#   inflating: valid_letters/letter_9888.png
#   inflating: valid_letters/letter_989.png
#   inflating: valid_letters/letter_9894.png
#   inflating: valid_letters/letter_990.png
#   inflating: valid_letters/letter_9901.png
#   inflating: valid_letters/letter_9902.png
#   inflating: valid_letters/letter_9903.png
#   inflating: valid_letters/letter_9904.png
#   inflating: valid_letters/letter_9905.png
#   inflating: valid_letters/letter_9906.png
#   inflating: valid_letters/letter_9907.png
#   inflating: valid_letters/letter_9908.png
#   inflating: valid_letters/letter_9909.png
#   inflating: valid_letters/letter_9910.png
#   inflating: valid_letters/letter_9911.png
#   inflating: valid_letters/letter_9912.png
#   inflating: valid_letters/letter_9914.png
#   inflating: valid_letters/letter_9916.png
#   inflating: valid_letters/letter_9917.png
#   inflating: valid_letters/letter_9931.png
#   inflating: valid_letters/letter_9932.png
#   inflating: valid_letters/letter_9933.png
#   inflating: valid_letters/letter_9934.png
#   inflating: valid_letters/letter_9935.png
#   inflating: valid_letters/letter_9936.png
#   inflating: valid_letters/letter_9937.png
#   inflating: valid_letters/letter_994.png
#   inflating: valid_letters/letter_9940.png
#   inflating: valid_letters/letter_9941.png
#   inflating: valid_letters/letter_9943.png
#   inflating: valid_letters/letter_9944.png
#   inflating: valid_letters/letter_9945.png
#   inflating: valid_letters/letter_9946.png
#   inflating: valid_letters/letter_9948.png
#   inflating: valid_letters/letter_9949.png
#   inflating: valid_letters/letter_995.png
#   inflating: valid_letters/letter_9952.png
#   inflating: valid_letters/letter_9955.png
#   inflating: valid_letters/letter_9956.png
#   inflating: valid_letters/letter_9957.png
#   inflating: valid_letters/letter_9967.png
#   inflating: valid_letters/letter_9969.png
#   inflating: valid_letters/letter_997.png
#   inflating: valid_letters/letter_9971.png
#   inflating: valid_letters/letter_9973.png
#   inflating: valid_letters/letter_9974.png
#   inflating: valid_letters/letter_9977.png
#   inflating: valid_letters/letter_9978.png
#   inflating: valid_letters/letter_9979.png
#   inflating: valid_letters/letter_9980.png
#   inflating: valid_letters/letter_9981.png
#   inflating: valid_letters/letter_9989.png
#   inflating: valid_letters/letter_9990.png
#   inflating: valid_letters/letter_9991.png
#   inflating: valid_letters/letter_9996.png
#   inflating: valid_letters/letter_9997.png
#   inflating: valid_letters/letter_9998.png
#   inflating: valid_letters/letter_9999.png
#   inflating: written_letters_test.csv
#   inflating: written_letters_train.csv
#   inflating: written_letters_validation.csv

# %% [markdown]
# ## View Data

# %%
# Preparar el dataset
train_data = pd.read_csv('written_letters_train.csv')
valid_data = pd.read_csv('written_letters_validation.csv')

# %%
plt.figure(figsize=(2.5, 3.5))

for i in range(6):
    ax = plt.subplot(2, 3, i+1)
    img_dir = 'train_letters/'+train_data.loc[i, 'id']
    image = cv2.imread(img_dir, cv2.IMREAD_GRAYSCALE)
    plt.imshow(image, cmap = 'gray')
    plt.title(train_data.loc[i, 'nombre'], fontsize=15)
    plt.axis('off')

plt.subplots_adjust(wspace=0.2, hspace=0.5)

# %%
print("Number of NaNs in train set      : ", train_data['nombre'].isnull().sum())
print("Number of NaNs in validation set : ", valid_data['nombre'].isnull().sum())
# Out:
# Number of NaNs in train set      :  0
# Number of NaNs in validation set :  0

# %%
train_data.dropna(axis=0, inplace=True)
valid_data.dropna(axis=0, inplace=True)

# %%
train_data = train_data[train_data['nombre'] != 'UNREADABLE']
valid_data = valid_data[valid_data['nombre'] != 'UNREADABLE']

# %%
train_data['nombre'] = train_data['nombre'].str.upper()
valid_data['nombre'] = valid_data['nombre'].str.upper()

# %%
train_data.reset_index(inplace = True, drop=True)
valid_data.reset_index(inplace = True, drop=True)

# %%
letter_count = train_data['nombre'].value_counts()

letter_count[:10].plot(kind='barh')
plt.title('Distribució de lletres')
plt.xlabel('Lletra')
plt.ylabel('Quantitat de mostres')
plt.show()

print(letter_count[:10])
# Out:
# nombre
# A    21687
# E    18122
# L    14201
# N    10797
# O    10319
# R    10160
# U     9636
# I     8816
# S     5945
# C     5128
# Name: count, dtype: int64

# %% [markdown]
# ## Preprocessing Images for Training

# %%
class HandwritingDataset(Dataset):
    def __init__(self, root_dir, csv_file, transform=None):
        self.root_dir = root_dir
        self.df = pd.read_csv(csv_file)
        self.transform = transform
        self.label_encoder = LabelEncoder()
        self.labels_encoded = self.label_encoder.fit_transform(self.df.iloc[:, 1])

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir, self.df.iloc[idx, 0])
        image = Image.open(img_name).convert("L")  # Convert to grayscale
        label = self.labels_encoded[idx]  # Use the encoded label

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
# Define transformations
transform = transforms.Compose([
    transforms.Resize((28, 28)),  # Resize images to a standard size
    transforms.ToTensor(),  # Convert image to tensor
])

# %% [markdown]
# Split the datasets:

# %%
# Combine the training and validation DataFrames
combined_data = pd.concat([train_data, valid_data])

# Separate features and labels
X = combined_data.drop(columns=['nombre'])
y = combined_data['nombre']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=300/(3000+300), stratify=y, random_state=42)

# Combine features and labels back into DataFrames
train_data = pd.concat([X_train, y_train], axis=1)
valid_data = pd.concat([X_valid, y_valid], axis=1)

# Verify the class distribution
print('Training class distribution:\n', train_data['nombre'].value_counts())
print('Validation class distribution:\n', valid_data['nombre'].value_counts())
# Out:
# Training class distribution:
#  nombre
# A    22216
# E    18677
# L    14574
# N    11079
# O    10659
# R    10438
# U     9905
# I     9020
# S     6086
# C     5290
# H     4984
# M     4635
# T     4588
# D     3708
# G     2651
# Y     2497
# B     2325
# P     1915
# V     1907
# F     1516
# X     1038
# Z      978
# K      950
# J      659
#        614
# -      584
# Q      195
# W      141
# '       27
# Name: count, dtype: int64
# Validation class distribution:
#  nombre
# A    2222
# E    1868
# L    1457
# N    1108
# O    1066
# R    1044
# U     991
# I     902
# S     609
# C     529
# H     498
# M     464
# T     459
# D     371
# G     265
# Y     250
# B     232
# P     191
# V     191
# F     151
# X     104
# Z      98
# K      95
# J      66
#        61
# -      58
# Q      19
# W      14
# '       3
# Name: count, dtype: int64

# %% [markdown]
# Balance the labels:

# %%
from sklearn.utils.class_weight import compute_class_weight

# Get the class labels
class_labels = train_data['nombre'].unique()
class_weights = compute_class_weight('balanced', classes=class_labels, y=train_data['nombre'])

# Convert to tensor
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)

# %%
# train_data, valid_data = train_test_split(data, test_size=0.1, stratify=data['label'], random_state=42)

# # Adjusting the size of train_data to 3000 samples
# train_data = train_data.sample(n=3000, random_state=42)

# # Adjusting the size of valid_data to 300 samples
# valid_data = valid_data.sample(n=300, random_state=42)

# %%
train_dataset = HandwritingDataset(root_dir='train_letters/', csv_file="written_letters_train.csv", transform=transform)
valid_dataset = HandwritingDataset(root_dir='valid_letters/', csv_file="written_letters_validation.csv", transform=transform)

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# Verify de data loaders work correctly:

# %%
for i, (images, labels) in enumerate(train_loader):
    print(f"Batch {i}:")
    print(images.shape)  # This will give you the shape of the batch of images
    print(labels.shape)  # And this will give you the shape of the batch of labels
    break  # Just to demonstrate, stop after the first batch
# Out:
# Batch 0:
# torch.Size([32, 1, 28, 28])
# torch.Size([32])

# %% [markdown]
# ## Training function

# %%
class EarlyStopping:
    def __init__(self, patience=5, delta=0):
        self.patience = patience
        self.delta = delta
        self.best_score = None
        self.counter = 0
        self.early_stop = False
        self.best_model_wts = None

    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        self.best_model_wts = copy.deepcopy(model.state_dict())
        torch.save(self.best_model_wts, 'checkpoint.pt')

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25):
    since = time.time()

    acc_history = {"train": [], "valid": []}
    losses = {"train": [], "valid": []}  # Store average losses per epoch

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    early_stopping = EarlyStopping(patience=5, delta=0)

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # Save the average loss for the epoch
            losses[phase].append(epoch_loss)

            if phase == 'valid':
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_wts = copy.deepcopy(model.state_dict())
                early_stopping(epoch_loss, model)

            acc_history[phase].append(epoch_acc)

        print()

        if early_stopping.early_stop:
            print("Early stopping")
            break

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    if early_stopping.best_model_wts is not None:
        model.load_state_dict(early_stopping.best_model_wts)
    else:
        model.load_state_dict(best_model_wts)
    return model, acc_history, losses

# %% [markdown]
# ## Initialize model

# %%
def initialize_model(num_classes):
    # Resnet18
    model = models.resnet18(weights = None)

    model.conv1 = nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)

    model.fc = nn.Sequential(
        nn.Dropout(0.5),
        nn.Linear(in_features=512, out_features=num_classes, bias=True))

    input_size = 224

    return model, input_size

alphabets = u"ABCDEFGHIJKLMNOPQRSTUVWXYZ-' "
# Number of classes in the dataset
num_classes = len(alphabets)
print('num classes:', num_classes)

# Initialize the model
model, input_size = initialize_model(num_classes)

# Print the model we just instantiated
print(model)
# Out:
# num classes: 29
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=512, out_features=29, bias=True)
#   )
# )

# %% [markdown]
# ## Run Training and Validation

# %%
# Send the model to GPU
model = model.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss(weight=class_weights)

# Number of epochs to train fors
num_epochs = 15

optimizer_ft = optim.Adam(model.parameters(), lr=0.00001)

dataloaders_dict = {"train": train_loader, "valid": valid_loader}

# Train and evaluate
model, hist, losses = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/14
# ----------
# train Loss: 1.0883 Acc: 0.5556
# valid Loss: 0.5006 Acc: 0.7614
#
# Epoch 1/14
# ----------
# train Loss: 0.4595 Acc: 0.7739
# valid Loss: 0.3801 Acc: 0.8181
#
# Epoch 2/14
# ----------
# train Loss: 0.3481 Acc: 0.8196
# valid Loss: 0.3360 Acc: 0.8603
#
# Epoch 3/14
# ----------
# train Loss: 0.2873 Acc: 0.8520
# valid Loss: 0.3193 Acc: 0.8724
#
# Epoch 4/14
# ----------
# train Loss: 0.2483 Acc: 0.8731
# valid Loss: 0.3239 Acc: 0.8903
#
# Epoch 5/14
# ----------
# train Loss: 0.2246 Acc: 0.8852
# valid Loss: 0.3297 Acc: 0.9000
#
# Epoch 6/14
# ----------
# train Loss: 0.2022 Acc: 0.8978
# valid Loss: 0.3272 Acc: 0.9059
#
# Epoch 7/14
# ----------
# train Loss: 0.1800 Acc: 0.9066
# valid Loss: 0.3341 Acc: 0.9106
#
# Epoch 8/14
# ----------
# train Loss: 0.1683 Acc: 0.9118
# valid Loss: 0.3169 Acc: 0.9101
#
# Epoch 9/14
# ----------
# train Loss: 0.1531 Acc: 0.9172
# valid Loss: 0.3324 Acc: 0.9109
#
# Epoch 10/14
# ----------
# train Loss: 0.1417 Acc: 0.9219
# valid Loss: 0.3356 Acc: 0.9152
#
# Epoch 11/14
# ----------
# train Loss: 0.1306 Acc: 0.9260
# valid Loss: 0.3589 Acc: 0.9163
#
# Epoch 12/14
# ----------
# train Loss: 0.1226 Acc: 0.9312
# valid Loss: 0.3460 Acc: 0.9157
#
# Epoch 13/14
# ----------
# train Loss: 0.1132 Acc: 0.9340
# valid Loss: 0.3667 Acc: 0.9186
#
# Early stopping
# Training complete in 35m 27s
# Best val Acc: 0.918583

# %%
torch.save(model.state_dict(), 'cnn_model_v4.pth')

# %%
train_losses = losses["train"]
val_losses = losses["valid"]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot the training and validation losses
ax1.plot(train_losses, label='Training loss')
ax1.plot(val_losses, label='Validation loss')
ax1.set_title('Loss over epochs')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()
ax1.grid(True)

train_accuracies = [acc.cpu().detach().numpy() for acc in hist['train']]
val_accuracies = [acc.cpu().detach().numpy() for acc in hist['valid']]

# Plot the training and validation accuracies
ax2.plot(train_accuracies, label='Training accuracy')
ax2.plot(val_accuracies, label='Validation accuracy')
ax2.set_title('Accuracy over epochs')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend()
ax2.grid(True)

plt.show()
