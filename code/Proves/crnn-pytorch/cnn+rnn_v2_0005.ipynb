# %% [markdown]
# #**CNN + RNN model**

# %% [markdown]
# # Load the data

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.14)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.4)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.7)

# %%
# !kaggle datasets download -d landlord/handwriting-recognition
# !unzip handwriting-recognition.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: validation_v2/validation/VALIDATION_5003.jpg
#   inflating: validation_v2/validation/VALIDATION_5004.jpg
#   inflating: validation_v2/validation/VALIDATION_5005.jpg
#   inflating: validation_v2/validation/VALIDATION_5006.jpg
#   inflating: validation_v2/validation/VALIDATION_5007.jpg
#   inflating: validation_v2/validation/VALIDATION_5008.jpg
#   inflating: validation_v2/validation/VALIDATION_5009.jpg
#   inflating: validation_v2/validation/VALIDATION_5010.jpg
#   inflating: validation_v2/validation/VALIDATION_5011.jpg
#   inflating: validation_v2/validation/VALIDATION_5012.jpg
#   inflating: validation_v2/validation/VALIDATION_5013.jpg
#   inflating: validation_v2/validation/VALIDATION_5014.jpg
#   inflating: validation_v2/validation/VALIDATION_5015.jpg
#   inflating: validation_v2/validation/VALIDATION_5016.jpg
#   inflating: validation_v2/validation/VALIDATION_5017.jpg
#   inflating: validation_v2/validation/VALIDATION_5018.jpg
#   inflating: validation_v2/validation/VALIDATION_5019.jpg
#   inflating: validation_v2/validation/VALIDATION_5020.jpg
#   inflating: validation_v2/validation/VALIDATION_5021.jpg
#   inflating: validation_v2/validation/VALIDATION_5022.jpg
#   inflating: validation_v2/validation/VALIDATION_5023.jpg
#   inflating: validation_v2/validation/VALIDATION_5024.jpg
#   inflating: validation_v2/validation/VALIDATION_5025.jpg
#   inflating: validation_v2/validation/VALIDATION_5026.jpg
#   inflating: validation_v2/validation/VALIDATION_5027.jpg
#   inflating: validation_v2/validation/VALIDATION_5028.jpg
#   inflating: validation_v2/validation/VALIDATION_5029.jpg
#   inflating: validation_v2/validation/VALIDATION_5030.jpg
#   inflating: validation_v2/validation/VALIDATION_5031.jpg
#   inflating: validation_v2/validation/VALIDATION_5032.jpg
#   inflating: validation_v2/validation/VALIDATION_5033.jpg
#   inflating: validation_v2/validation/VALIDATION_5034.jpg
#   inflating: validation_v2/validation/VALIDATION_5035.jpg
#   inflating: validation_v2/validation/VALIDATION_5036.jpg
#   inflating: validation_v2/validation/VALIDATION_5037.jpg
#   inflating: validation_v2/validation/VALIDATION_5038.jpg
#   inflating: validation_v2/validation/VALIDATION_5039.jpg
#   inflating: validation_v2/validation/VALIDATION_5040.jpg
#   inflating: validation_v2/validation/VALIDATION_5041.jpg
#   inflating: validation_v2/validation/VALIDATION_5042.jpg
#   inflating: validation_v2/validation/VALIDATION_5043.jpg
#   inflating: validation_v2/validation/VALIDATION_5044.jpg
#   inflating: validation_v2/validation/VALIDATION_5045.jpg
#   inflating: validation_v2/validation/VALIDATION_5046.jpg
#   inflating: validation_v2/validation/VALIDATION_5047.jpg
#   inflating: validation_v2/validation/VALIDATION_5048.jpg
#   inflating: validation_v2/validation/VALIDATION_5049.jpg
#   inflating: validation_v2/validation/VALIDATION_5050.jpg
#   inflating: validation_v2/validation/VALIDATION_5051.jpg
#   inflating: validation_v2/validation/VALIDATION_5052.jpg
#   inflating: validation_v2/validation/VALIDATION_5053.jpg
#   inflating: validation_v2/validation/VALIDATION_5054.jpg
#   inflating: validation_v2/validation/VALIDATION_5055.jpg
#   inflating: validation_v2/validation/VALIDATION_5056.jpg
#   inflating: validation_v2/validation/VALIDATION_5057.jpg
#   inflating: validation_v2/validation/VALIDATION_5058.jpg
#   inflating: validation_v2/validation/VALIDATION_5059.jpg
#   inflating: validation_v2/validation/VALIDATION_5060.jpg
#   inflating: validation_v2/validation/VALIDATION_5061.jpg
#   inflating: validation_v2/validation/VALIDATION_5062.jpg
#   inflating: validation_v2/validation/VALIDATION_5063.jpg
#   inflating: validation_v2/validation/VALIDATION_5064.jpg
#   inflating: validation_v2/validation/VALIDATION_5065.jpg
#   inflating: validation_v2/validation/VALIDATION_5066.jpg
#   inflating: validation_v2/validation/VALIDATION_5067.jpg
#   inflating: validation_v2/validation/VALIDATION_5068.jpg
#   inflating: validation_v2/validation/VALIDATION_5069.jpg
#   inflating: validation_v2/validation/VALIDATION_5070.jpg
#   inflating: validation_v2/validation/VALIDATION_5071.jpg
#   inflating: validation_v2/validation/VALIDATION_5072.jpg
#   inflating: validation_v2/validation/VALIDATION_5073.jpg
#   inflating: validation_v2/validation/VALIDATION_5074.jpg
#   inflating: validation_v2/validation/VALIDATION_5075.jpg
#   inflating: validation_v2/validation/VALIDATION_5076.jpg
#   inflating: validation_v2/validation/VALIDATION_5077.jpg
#   inflating: validation_v2/validation/VALIDATION_5078.jpg
#   inflating: validation_v2/validation/VALIDATION_5079.jpg
#   inflating: validation_v2/validation/VALIDATION_5080.jpg
#   inflating: validation_v2/validation/VALIDATION_5081.jpg
#   inflating: validation_v2/validation/VALIDATION_5082.jpg
#   inflating: validation_v2/validation/VALIDATION_5083.jpg
#   inflating: validation_v2/validation/VALIDATION_5084.jpg
#   inflating: validation_v2/validation/VALIDATION_5085.jpg
#   inflating: validation_v2/validation/VALIDATION_5086.jpg
#   inflating: validation_v2/validation/VALIDATION_5087.jpg
#   inflating: validation_v2/validation/VALIDATION_5088.jpg
#   inflating: validation_v2/validation/VALIDATION_5089.jpg
#   inflating: validation_v2/validation/VALIDATION_5090.jpg
#   inflating: validation_v2/validation/VALIDATION_5091.jpg
#   inflating: validation_v2/validation/VALIDATION_5092.jpg
#   inflating: validation_v2/validation/VALIDATION_5093.jpg
#   inflating: validation_v2/validation/VALIDATION_5094.jpg
#   inflating: validation_v2/validation/VALIDATION_5095.jpg
#   inflating: validation_v2/validation/VALIDATION_5096.jpg
#   inflating: validation_v2/validation/VALIDATION_5097.jpg
#   inflating: validation_v2/validation/VALIDATION_5098.jpg
#   inflating: validation_v2/validation/VALIDATION_5099.jpg
#   inflating: validation_v2/validation/VALIDATION_5100.jpg
#   inflating: validation_v2/validation/VALIDATION_5101.jpg
#   inflating: validation_v2/validation/VALIDATION_5102.jpg
#   inflating: validation_v2/validation/VALIDATION_5103.jpg
#   inflating: validation_v2/validation/VALIDATION_5104.jpg
#   inflating: validation_v2/validation/VALIDATION_5105.jpg
#   inflating: validation_v2/validation/VALIDATION_5106.jpg
#   inflating: validation_v2/validation/VALIDATION_5107.jpg
#   inflating: validation_v2/validation/VALIDATION_5108.jpg
#   inflating: validation_v2/validation/VALIDATION_5109.jpg
#   inflating: validation_v2/validation/VALIDATION_5110.jpg
#   inflating: validation_v2/validation/VALIDATION_5111.jpg
#   inflating: validation_v2/validation/VALIDATION_5112.jpg
#   inflating: validation_v2/validation/VALIDATION_5113.jpg
#   inflating: validation_v2/validation/VALIDATION_5114.jpg
#   inflating: validation_v2/validation/VALIDATION_5115.jpg
#   inflating: validation_v2/validation/VALIDATION_5116.jpg
#   inflating: validation_v2/validation/VALIDATION_5117.jpg
#   inflating: validation_v2/validation/VALIDATION_5118.jpg
#   inflating: validation_v2/validation/VALIDATION_5119.jpg
#   inflating: validation_v2/validation/VALIDATION_5120.jpg
#   inflating: validation_v2/validation/VALIDATION_5121.jpg
#   inflating: validation_v2/validation/VALIDATION_5122.jpg
#   inflating: validation_v2/validation/VALIDATION_5123.jpg
#   inflating: validation_v2/validation/VALIDATION_5124.jpg
#   inflating: validation_v2/validation/VALIDATION_5125.jpg
#   inflating: validation_v2/validation/VALIDATION_5126.jpg
#   inflating: validation_v2/validation/VALIDATION_5127.jpg
#   inflating: validation_v2/validation/VALIDATION_5128.jpg
#   inflating: validation_v2/validation/VALIDATION_5129.jpg
#   inflating: validation_v2/validation/VALIDATION_5130.jpg
#   inflating: validation_v2/validation/VALIDATION_5131.jpg
#   inflating: validation_v2/validation/VALIDATION_5132.jpg
#   inflating: validation_v2/validation/VALIDATION_5133.jpg
#   inflating: validation_v2/validation/VALIDATION_5134.jpg
#   inflating: validation_v2/validation/VALIDATION_5135.jpg
#   inflating: validation_v2/validation/VALIDATION_5136.jpg
#   inflating: validation_v2/validation/VALIDATION_5137.jpg
#   inflating: validation_v2/validation/VALIDATION_5138.jpg
#   inflating: validation_v2/validation/VALIDATION_5139.jpg
#   inflating: validation_v2/validation/VALIDATION_5140.jpg
#   inflating: validation_v2/validation/VALIDATION_5141.jpg
#   inflating: validation_v2/validation/VALIDATION_5142.jpg
#   inflating: validation_v2/validation/VALIDATION_5143.jpg
#   inflating: validation_v2/validation/VALIDATION_5144.jpg
#   inflating: validation_v2/validation/VALIDATION_5145.jpg
#   inflating: validation_v2/validation/VALIDATION_5146.jpg
#   inflating: validation_v2/validation/VALIDATION_5147.jpg
#   inflating: validation_v2/validation/VALIDATION_5148.jpg
#   inflating: validation_v2/validation/VALIDATION_5149.jpg
#   inflating: validation_v2/validation/VALIDATION_5150.jpg
#   inflating: validation_v2/validation/VALIDATION_5151.jpg
#   inflating: validation_v2/validation/VALIDATION_5152.jpg
#   inflating: validation_v2/validation/VALIDATION_5153.jpg
#   inflating: validation_v2/validation/VALIDATION_5154.jpg
#   inflating: validation_v2/validation/VALIDATION_5155.jpg
#   inflating: validation_v2/validation/VALIDATION_5156.jpg
#   inflating: validation_v2/validation/VALIDATION_5157.jpg
#   inflating: validation_v2/validation/VALIDATION_5158.jpg
#   inflating: validation_v2/validation/VALIDATION_5159.jpg
#   inflating: validation_v2/validation/VALIDATION_5160.jpg
#   inflating: validation_v2/validation/VALIDATION_5161.jpg
#   inflating: validation_v2/validation/VALIDATION_5162.jpg
#   inflating: validation_v2/validation/VALIDATION_5163.jpg
#   inflating: validation_v2/validation/VALIDATION_5164.jpg
#   inflating: validation_v2/validation/VALIDATION_5165.jpg
#   inflating: validation_v2/validation/VALIDATION_5166.jpg
#   inflating: validation_v2/validation/VALIDATION_5167.jpg
#   inflating: validation_v2/validation/VALIDATION_5168.jpg
#   inflating: validation_v2/validation/VALIDATION_5169.jpg
#   inflating: validation_v2/validation/VALIDATION_5170.jpg
#   inflating: validation_v2/validation/VALIDATION_5171.jpg
#   inflating: validation_v2/validation/VALIDATION_5172.jpg
#   inflating: validation_v2/validation/VALIDATION_5173.jpg
#   inflating: validation_v2/validation/VALIDATION_5174.jpg
#   inflating: validation_v2/validation/VALIDATION_5175.jpg
#   inflating: validation_v2/validation/VALIDATION_5176.jpg
#   inflating: validation_v2/validation/VALIDATION_5177.jpg
#   inflating: validation_v2/validation/VALIDATION_5178.jpg
#   inflating: validation_v2/validation/VALIDATION_5179.jpg
#   inflating: validation_v2/validation/VALIDATION_5180.jpg
#   inflating: validation_v2/validation/VALIDATION_5181.jpg
#   inflating: validation_v2/validation/VALIDATION_5182.jpg
#   inflating: validation_v2/validation/VALIDATION_5183.jpg
#   inflating: validation_v2/validation/VALIDATION_5184.jpg
#   inflating: validation_v2/validation/VALIDATION_5185.jpg
#   inflating: validation_v2/validation/VALIDATION_5186.jpg
#   inflating: validation_v2/validation/VALIDATION_5187.jpg
#   inflating: validation_v2/validation/VALIDATION_5188.jpg
#   inflating: validation_v2/validation/VALIDATION_5189.jpg
#   inflating: validation_v2/validation/VALIDATION_5190.jpg
#   inflating: validation_v2/validation/VALIDATION_5191.jpg
#   inflating: validation_v2/validation/VALIDATION_5192.jpg
#   inflating: validation_v2/validation/VALIDATION_5193.jpg
#   inflating: validation_v2/validation/VALIDATION_5194.jpg
#   inflating: validation_v2/validation/VALIDATION_5195.jpg
#   inflating: validation_v2/validation/VALIDATION_5196.jpg
#   inflating: validation_v2/validation/VALIDATION_5197.jpg
#   inflating: validation_v2/validation/VALIDATION_5198.jpg
#   inflating: validation_v2/validation/VALIDATION_5199.jpg
#   inflating: validation_v2/validation/VALIDATION_5200.jpg
#   inflating: validation_v2/validation/VALIDATION_5201.jpg
#   inflating: validation_v2/validation/VALIDATION_5202.jpg
#   inflating: validation_v2/validation/VALIDATION_5203.jpg
#   inflating: validation_v2/validation/VALIDATION_5204.jpg
#   inflating: validation_v2/validation/VALIDATION_5205.jpg
#   inflating: validation_v2/validation/VALIDATION_5206.jpg
#   inflating: validation_v2/validation/VALIDATION_5207.jpg
#   inflating: validation_v2/validation/VALIDATION_5208.jpg
#   inflating: validation_v2/validation/VALIDATION_5209.jpg
#   inflating: validation_v2/validation/VALIDATION_5210.jpg
#   inflating: validation_v2/validation/VALIDATION_5211.jpg
#   inflating: validation_v2/validation/VALIDATION_5212.jpg
#   inflating: validation_v2/validation/VALIDATION_5213.jpg
#   inflating: validation_v2/validation/VALIDATION_5214.jpg
#   inflating: validation_v2/validation/VALIDATION_5215.jpg
#   inflating: validation_v2/validation/VALIDATION_5216.jpg
#   inflating: validation_v2/validation/VALIDATION_5217.jpg
#   inflating: validation_v2/validation/VALIDATION_5218.jpg
#   inflating: validation_v2/validation/VALIDATION_5219.jpg
#   inflating: validation_v2/validation/VALIDATION_5220.jpg
#   inflating: validation_v2/validation/VALIDATION_5221.jpg
#   inflating: validation_v2/validation/VALIDATION_5222.jpg
#   inflating: validation_v2/validation/VALIDATION_5223.jpg
#   inflating: validation_v2/validation/VALIDATION_5224.jpg
#   inflating: validation_v2/validation/VALIDATION_5225.jpg
#   inflating: validation_v2/validation/VALIDATION_5226.jpg
#   inflating: validation_v2/validation/VALIDATION_5227.jpg
#   inflating: validation_v2/validation/VALIDATION_5228.jpg
#   inflating: validation_v2/validation/VALIDATION_5229.jpg
#   inflating: validation_v2/validation/VALIDATION_5230.jpg
#   inflating: validation_v2/validation/VALIDATION_5231.jpg
#   inflating: validation_v2/validation/VALIDATION_5232.jpg
#   inflating: validation_v2/validation/VALIDATION_5233.jpg
#   inflating: validation_v2/validation/VALIDATION_5234.jpg
#   inflating: validation_v2/validation/VALIDATION_5235.jpg
#   inflating: validation_v2/validation/VALIDATION_5236.jpg
#   inflating: validation_v2/validation/VALIDATION_5237.jpg
#   inflating: validation_v2/validation/VALIDATION_5238.jpg
#   inflating: validation_v2/validation/VALIDATION_5239.jpg
#   inflating: validation_v2/validation/VALIDATION_5240.jpg
#   inflating: validation_v2/validation/VALIDATION_5241.jpg
#   inflating: validation_v2/validation/VALIDATION_5242.jpg
#   inflating: validation_v2/validation/VALIDATION_5243.jpg
#   inflating: validation_v2/validation/VALIDATION_5244.jpg
#   inflating: validation_v2/validation/VALIDATION_5245.jpg
#   inflating: validation_v2/validation/VALIDATION_5246.jpg
#   inflating: validation_v2/validation/VALIDATION_5247.jpg
#   inflating: validation_v2/validation/VALIDATION_5248.jpg
#   inflating: validation_v2/validation/VALIDATION_5249.jpg
#   inflating: validation_v2/validation/VALIDATION_5250.jpg
#   inflating: validation_v2/validation/VALIDATION_5251.jpg
#   inflating: validation_v2/validation/VALIDATION_5252.jpg
#   inflating: validation_v2/validation/VALIDATION_5253.jpg
#   inflating: validation_v2/validation/VALIDATION_5254.jpg
#   inflating: validation_v2/validation/VALIDATION_5255.jpg
#   inflating: validation_v2/validation/VALIDATION_5256.jpg
#   inflating: validation_v2/validation/VALIDATION_5257.jpg
#   inflating: validation_v2/validation/VALIDATION_5258.jpg
#   inflating: validation_v2/validation/VALIDATION_5259.jpg
#   inflating: validation_v2/validation/VALIDATION_5260.jpg
#   inflating: validation_v2/validation/VALIDATION_5261.jpg
#   inflating: validation_v2/validation/VALIDATION_5262.jpg
#   inflating: validation_v2/validation/VALIDATION_5263.jpg
#   inflating: validation_v2/validation/VALIDATION_5264.jpg
#   inflating: validation_v2/validation/VALIDATION_5265.jpg
#   inflating: validation_v2/validation/VALIDATION_5266.jpg
#   inflating: validation_v2/validation/VALIDATION_5267.jpg
#   inflating: validation_v2/validation/VALIDATION_5268.jpg
#   inflating: validation_v2/validation/VALIDATION_5269.jpg
#   inflating: validation_v2/validation/VALIDATION_5270.jpg
#   inflating: validation_v2/validation/VALIDATION_5271.jpg
#   inflating: validation_v2/validation/VALIDATION_5272.jpg
#   inflating: validation_v2/validation/VALIDATION_5273.jpg
#   inflating: validation_v2/validation/VALIDATION_5274.jpg
#   inflating: validation_v2/validation/VALIDATION_5275.jpg
#   inflating: validation_v2/validation/VALIDATION_5276.jpg
#   inflating: validation_v2/validation/VALIDATION_5277.jpg
#   inflating: validation_v2/validation/VALIDATION_5278.jpg
#   inflating: validation_v2/validation/VALIDATION_5279.jpg
#   inflating: validation_v2/validation/VALIDATION_5280.jpg
#   inflating: validation_v2/validation/VALIDATION_5281.jpg
#   inflating: validation_v2/validation/VALIDATION_5282.jpg
#   inflating: validation_v2/validation/VALIDATION_5283.jpg
#   inflating: validation_v2/validation/VALIDATION_5284.jpg
#   inflating: validation_v2/validation/VALIDATION_5285.jpg
#   inflating: validation_v2/validation/VALIDATION_5286.jpg
#   inflating: validation_v2/validation/VALIDATION_5287.jpg
#   inflating: validation_v2/validation/VALIDATION_5288.jpg
#   inflating: validation_v2/validation/VALIDATION_5289.jpg
#   inflating: validation_v2/validation/VALIDATION_5290.jpg
#   inflating: validation_v2/validation/VALIDATION_5291.jpg
#   inflating: validation_v2/validation/VALIDATION_5292.jpg
#   inflating: validation_v2/validation/VALIDATION_5293.jpg
#   inflating: validation_v2/validation/VALIDATION_5294.jpg
#   inflating: validation_v2/validation/VALIDATION_5295.jpg
#   inflating: validation_v2/validation/VALIDATION_5296.jpg
#   inflating: validation_v2/validation/VALIDATION_5297.jpg
#   inflating: validation_v2/validation/VALIDATION_5298.jpg
#   inflating: validation_v2/validation/VALIDATION_5299.jpg
#   inflating: validation_v2/validation/VALIDATION_5300.jpg
#   inflating: validation_v2/validation/VALIDATION_5301.jpg
#   inflating: validation_v2/validation/VALIDATION_5302.jpg
#   inflating: validation_v2/validation/VALIDATION_5303.jpg
#   inflating: validation_v2/validation/VALIDATION_5304.jpg
#   inflating: validation_v2/validation/VALIDATION_5305.jpg
#   inflating: validation_v2/validation/VALIDATION_5306.jpg
#   inflating: validation_v2/validation/VALIDATION_5307.jpg
#   inflating: validation_v2/validation/VALIDATION_5308.jpg
#   inflating: validation_v2/validation/VALIDATION_5309.jpg
#   inflating: validation_v2/validation/VALIDATION_5310.jpg
#   inflating: validation_v2/validation/VALIDATION_5311.jpg
#   inflating: validation_v2/validation/VALIDATION_5312.jpg
#   inflating: validation_v2/validation/VALIDATION_5313.jpg
#   inflating: validation_v2/validation/VALIDATION_5314.jpg
#   inflating: validation_v2/validation/VALIDATION_5315.jpg
#   inflating: validation_v2/validation/VALIDATION_5316.jpg
#   inflating: validation_v2/validation/VALIDATION_5317.jpg
#   inflating: validation_v2/validation/VALIDATION_5318.jpg
#   inflating: validation_v2/validation/VALIDATION_5319.jpg
#   inflating: validation_v2/validation/VALIDATION_5320.jpg
#   inflating: validation_v2/validation/VALIDATION_5321.jpg
#   inflating: validation_v2/validation/VALIDATION_5322.jpg
#   inflating: validation_v2/validation/VALIDATION_5323.jpg
#   inflating: validation_v2/validation/VALIDATION_5324.jpg
#   inflating: validation_v2/validation/VALIDATION_5325.jpg
#   inflating: validation_v2/validation/VALIDATION_5326.jpg
#   inflating: validation_v2/validation/VALIDATION_5327.jpg
#   inflating: validation_v2/validation/VALIDATION_5328.jpg
#   inflating: validation_v2/validation/VALIDATION_5329.jpg
#   inflating: validation_v2/validation/VALIDATION_5330.jpg
#   inflating: validation_v2/validation/VALIDATION_5331.jpg
#   inflating: validation_v2/validation/VALIDATION_5332.jpg
#   inflating: validation_v2/validation/VALIDATION_5333.jpg
#   inflating: validation_v2/validation/VALIDATION_5334.jpg
#   inflating: validation_v2/validation/VALIDATION_5335.jpg
#   inflating: validation_v2/validation/VALIDATION_5336.jpg
#   inflating: validation_v2/validation/VALIDATION_5337.jpg
#   inflating: validation_v2/validation/VALIDATION_5338.jpg
#   inflating: validation_v2/validation/VALIDATION_5339.jpg
#   inflating: validation_v2/validation/VALIDATION_5340.jpg
#   inflating: validation_v2/validation/VALIDATION_5341.jpg
#   inflating: validation_v2/validation/VALIDATION_5342.jpg
#   inflating: validation_v2/validation/VALIDATION_5343.jpg
#   inflating: validation_v2/validation/VALIDATION_5344.jpg
#   inflating: validation_v2/validation/VALIDATION_5345.jpg
#   inflating: validation_v2/validation/VALIDATION_5346.jpg
#   inflating: validation_v2/validation/VALIDATION_5347.jpg
#   inflating: validation_v2/validation/VALIDATION_5348.jpg
#   inflating: validation_v2/validation/VALIDATION_5349.jpg
#   inflating: validation_v2/validation/VALIDATION_5350.jpg
#   inflating: validation_v2/validation/VALIDATION_5351.jpg
#   inflating: validation_v2/validation/VALIDATION_5352.jpg
#   inflating: validation_v2/validation/VALIDATION_5353.jpg
#   inflating: validation_v2/validation/VALIDATION_5354.jpg
#   inflating: validation_v2/validation/VALIDATION_5355.jpg
#   inflating: validation_v2/validation/VALIDATION_5356.jpg
#   inflating: validation_v2/validation/VALIDATION_5357.jpg
#   inflating: validation_v2/validation/VALIDATION_5358.jpg
#   inflating: validation_v2/validation/VALIDATION_5359.jpg
#   inflating: validation_v2/validation/VALIDATION_5360.jpg
#   inflating: validation_v2/validation/VALIDATION_5361.jpg
#   inflating: validation_v2/validation/VALIDATION_5362.jpg
#   inflating: validation_v2/validation/VALIDATION_5363.jpg
#   inflating: validation_v2/validation/VALIDATION_5364.jpg
#   inflating: validation_v2/validation/VALIDATION_5365.jpg
#   inflating: validation_v2/validation/VALIDATION_5366.jpg
#   inflating: validation_v2/validation/VALIDATION_5367.jpg
#   inflating: validation_v2/validation/VALIDATION_5368.jpg
#   inflating: validation_v2/validation/VALIDATION_5369.jpg
#   inflating: validation_v2/validation/VALIDATION_5370.jpg
#   inflating: validation_v2/validation/VALIDATION_5371.jpg
#   inflating: validation_v2/validation/VALIDATION_5372.jpg
#   inflating: validation_v2/validation/VALIDATION_5373.jpg
#   inflating: validation_v2/validation/VALIDATION_5374.jpg
#   inflating: validation_v2/validation/VALIDATION_5375.jpg
#   inflating: validation_v2/validation/VALIDATION_5376.jpg
#   inflating: validation_v2/validation/VALIDATION_5377.jpg
#   inflating: validation_v2/validation/VALIDATION_5378.jpg
#   inflating: validation_v2/validation/VALIDATION_5379.jpg
#   inflating: validation_v2/validation/VALIDATION_5380.jpg
#   inflating: validation_v2/validation/VALIDATION_5381.jpg
#   inflating: validation_v2/validation/VALIDATION_5382.jpg
#   inflating: validation_v2/validation/VALIDATION_5383.jpg
#   inflating: validation_v2/validation/VALIDATION_5384.jpg
#   inflating: validation_v2/validation/VALIDATION_5385.jpg
#   inflating: validation_v2/validation/VALIDATION_5386.jpg
#   inflating: validation_v2/validation/VALIDATION_5387.jpg
#   inflating: validation_v2/validation/VALIDATION_5388.jpg
#   inflating: validation_v2/validation/VALIDATION_5389.jpg
#   inflating: validation_v2/validation/VALIDATION_5390.jpg
#   inflating: validation_v2/validation/VALIDATION_5391.jpg
#   inflating: validation_v2/validation/VALIDATION_5392.jpg
#   inflating: validation_v2/validation/VALIDATION_5393.jpg
#   inflating: validation_v2/validation/VALIDATION_5394.jpg
#   inflating: validation_v2/validation/VALIDATION_5395.jpg
#   inflating: validation_v2/validation/VALIDATION_5396.jpg
#   inflating: validation_v2/validation/VALIDATION_5397.jpg
#   inflating: validation_v2/validation/VALIDATION_5398.jpg
#   inflating: validation_v2/validation/VALIDATION_5399.jpg
#   inflating: validation_v2/validation/VALIDATION_5400.jpg
#   inflating: validation_v2/validation/VALIDATION_5401.jpg
#   inflating: validation_v2/validation/VALIDATION_5402.jpg
#   inflating: validation_v2/validation/VALIDATION_5403.jpg
#   inflating: validation_v2/validation/VALIDATION_5404.jpg
#   inflating: validation_v2/validation/VALIDATION_5405.jpg
#   inflating: validation_v2/validation/VALIDATION_5406.jpg
#   inflating: validation_v2/validation/VALIDATION_5407.jpg
#   inflating: validation_v2/validation/VALIDATION_5408.jpg
#   inflating: validation_v2/validation/VALIDATION_5409.jpg
#   inflating: validation_v2/validation/VALIDATION_5410.jpg
#   inflating: validation_v2/validation/VALIDATION_5411.jpg
#   inflating: validation_v2/validation/VALIDATION_5412.jpg
#   inflating: validation_v2/validation/VALIDATION_5413.jpg
#   inflating: validation_v2/validation/VALIDATION_5414.jpg
#   inflating: validation_v2/validation/VALIDATION_5415.jpg
#   inflating: validation_v2/validation/VALIDATION_5416.jpg
#   inflating: validation_v2/validation/VALIDATION_5417.jpg
#   inflating: validation_v2/validation/VALIDATION_5418.jpg
#   inflating: validation_v2/validation/VALIDATION_5419.jpg
#   inflating: validation_v2/validation/VALIDATION_5420.jpg
#   inflating: validation_v2/validation/VALIDATION_5421.jpg
#   inflating: validation_v2/validation/VALIDATION_5422.jpg
#   inflating: validation_v2/validation/VALIDATION_5423.jpg
#   inflating: validation_v2/validation/VALIDATION_5424.jpg
#   inflating: validation_v2/validation/VALIDATION_5425.jpg
#   inflating: validation_v2/validation/VALIDATION_5426.jpg
#   inflating: validation_v2/validation/VALIDATION_5427.jpg
#   inflating: validation_v2/validation/VALIDATION_5428.jpg
#   inflating: validation_v2/validation/VALIDATION_5429.jpg
#   inflating: validation_v2/validation/VALIDATION_5430.jpg
#   inflating: validation_v2/validation/VALIDATION_5431.jpg
#   inflating: validation_v2/validation/VALIDATION_5432.jpg
#   inflating: validation_v2/validation/VALIDATION_5433.jpg
#   inflating: validation_v2/validation/VALIDATION_5434.jpg
#   inflating: validation_v2/validation/VALIDATION_5435.jpg
#   inflating: validation_v2/validation/VALIDATION_5436.jpg
#   inflating: validation_v2/validation/VALIDATION_5437.jpg
#   inflating: validation_v2/validation/VALIDATION_5438.jpg
#   inflating: validation_v2/validation/VALIDATION_5439.jpg
#   inflating: validation_v2/validation/VALIDATION_5440.jpg
#   inflating: validation_v2/validation/VALIDATION_5441.jpg
#   inflating: validation_v2/validation/VALIDATION_5442.jpg
#   inflating: validation_v2/validation/VALIDATION_5443.jpg
#   inflating: validation_v2/validation/VALIDATION_5444.jpg
#   inflating: validation_v2/validation/VALIDATION_5445.jpg
#   inflating: validation_v2/validation/VALIDATION_5446.jpg
#   inflating: validation_v2/validation/VALIDATION_5447.jpg
#   inflating: validation_v2/validation/VALIDATION_5448.jpg
#   inflating: validation_v2/validation/VALIDATION_5449.jpg
#   inflating: validation_v2/validation/VALIDATION_5450.jpg
#   inflating: validation_v2/validation/VALIDATION_5451.jpg
#   inflating: validation_v2/validation/VALIDATION_5452.jpg
#   inflating: validation_v2/validation/VALIDATION_5453.jpg
#   inflating: validation_v2/validation/VALIDATION_5454.jpg
#   inflating: validation_v2/validation/VALIDATION_5455.jpg
#   inflating: validation_v2/validation/VALIDATION_5456.jpg
#   inflating: validation_v2/validation/VALIDATION_5457.jpg
#   inflating: validation_v2/validation/VALIDATION_5458.jpg
#   inflating: validation_v2/validation/VALIDATION_5459.jpg
#   inflating: validation_v2/validation/VALIDATION_5460.jpg
#   inflating: validation_v2/validation/VALIDATION_5461.jpg
#   inflating: validation_v2/validation/VALIDATION_5462.jpg
#   inflating: validation_v2/validation/VALIDATION_5463.jpg
#   inflating: validation_v2/validation/VALIDATION_5464.jpg
#   inflating: validation_v2/validation/VALIDATION_5465.jpg
#   inflating: validation_v2/validation/VALIDATION_5466.jpg
#   inflating: validation_v2/validation/VALIDATION_5467.jpg
#   inflating: validation_v2/validation/VALIDATION_5468.jpg
#   inflating: validation_v2/validation/VALIDATION_5469.jpg
#   inflating: validation_v2/validation/VALIDATION_5470.jpg
#   inflating: validation_v2/validation/VALIDATION_5471.jpg
#   inflating: validation_v2/validation/VALIDATION_5472.jpg
#   inflating: validation_v2/validation/VALIDATION_5473.jpg
#   inflating: validation_v2/validation/VALIDATION_5474.jpg
#   inflating: validation_v2/validation/VALIDATION_5475.jpg
#   inflating: validation_v2/validation/VALIDATION_5476.jpg
#   inflating: validation_v2/validation/VALIDATION_5477.jpg
#   inflating: validation_v2/validation/VALIDATION_5478.jpg
#   inflating: validation_v2/validation/VALIDATION_5479.jpg
#   inflating: validation_v2/validation/VALIDATION_5480.jpg
#   inflating: validation_v2/validation/VALIDATION_5481.jpg
#   inflating: validation_v2/validation/VALIDATION_5482.jpg
#   inflating: validation_v2/validation/VALIDATION_5483.jpg
#   inflating: validation_v2/validation/VALIDATION_5484.jpg
#   inflating: validation_v2/validation/VALIDATION_5485.jpg
#   inflating: validation_v2/validation/VALIDATION_5486.jpg
#   inflating: validation_v2/validation/VALIDATION_5487.jpg
#   inflating: validation_v2/validation/VALIDATION_5488.jpg
#   inflating: validation_v2/validation/VALIDATION_5489.jpg
#   inflating: validation_v2/validation/VALIDATION_5490.jpg
#   inflating: validation_v2/validation/VALIDATION_5491.jpg
#   inflating: validation_v2/validation/VALIDATION_5492.jpg
#   inflating: validation_v2/validation/VALIDATION_5493.jpg
#   inflating: validation_v2/validation/VALIDATION_5494.jpg
#   inflating: validation_v2/validation/VALIDATION_5495.jpg
#   inflating: validation_v2/validation/VALIDATION_5496.jpg
#   inflating: validation_v2/validation/VALIDATION_5497.jpg
#   inflating: validation_v2/validation/VALIDATION_5498.jpg
#   inflating: validation_v2/validation/VALIDATION_5499.jpg
#   inflating: validation_v2/validation/VALIDATION_5500.jpg
#   inflating: validation_v2/validation/VALIDATION_5501.jpg
#   inflating: validation_v2/validation/VALIDATION_5502.jpg
#   inflating: validation_v2/validation/VALIDATION_5503.jpg
#   inflating: validation_v2/validation/VALIDATION_5504.jpg
#   inflating: validation_v2/validation/VALIDATION_5505.jpg
#   inflating: validation_v2/validation/VALIDATION_5506.jpg
#   inflating: validation_v2/validation/VALIDATION_5507.jpg
#   inflating: validation_v2/validation/VALIDATION_5508.jpg
#   inflating: validation_v2/validation/VALIDATION_5509.jpg
#   inflating: validation_v2/validation/VALIDATION_5510.jpg
#   inflating: validation_v2/validation/VALIDATION_5511.jpg
#   inflating: validation_v2/validation/VALIDATION_5512.jpg
#   inflating: validation_v2/validation/VALIDATION_5513.jpg
#   inflating: validation_v2/validation/VALIDATION_5514.jpg
#   inflating: validation_v2/validation/VALIDATION_5515.jpg
#   inflating: validation_v2/validation/VALIDATION_5516.jpg
#   inflating: validation_v2/validation/VALIDATION_5517.jpg
#   inflating: validation_v2/validation/VALIDATION_5518.jpg
#   inflating: validation_v2/validation/VALIDATION_5519.jpg
#   inflating: validation_v2/validation/VALIDATION_5520.jpg
#   inflating: validation_v2/validation/VALIDATION_5521.jpg
#   inflating: validation_v2/validation/VALIDATION_5522.jpg
#   inflating: validation_v2/validation/VALIDATION_5523.jpg
#   inflating: validation_v2/validation/VALIDATION_5524.jpg
#   inflating: validation_v2/validation/VALIDATION_5525.jpg
#   inflating: validation_v2/validation/VALIDATION_5526.jpg
#   inflating: validation_v2/validation/VALIDATION_5527.jpg
#   inflating: validation_v2/validation/VALIDATION_5528.jpg
#   inflating: validation_v2/validation/VALIDATION_5529.jpg
#   inflating: validation_v2/validation/VALIDATION_5530.jpg
#   inflating: validation_v2/validation/VALIDATION_5531.jpg
#   inflating: validation_v2/validation/VALIDATION_5532.jpg
#   inflating: validation_v2/validation/VALIDATION_5533.jpg
#   inflating: validation_v2/validation/VALIDATION_5534.jpg
#   inflating: validation_v2/validation/VALIDATION_5535.jpg
#   inflating: validation_v2/validation/VALIDATION_5536.jpg
#   inflating: validation_v2/validation/VALIDATION_5537.jpg
#   inflating: validation_v2/validation/VALIDATION_5538.jpg
#   inflating: validation_v2/validation/VALIDATION_5539.jpg
#   inflating: validation_v2/validation/VALIDATION_5540.jpg
#   inflating: validation_v2/validation/VALIDATION_5541.jpg
#   inflating: validation_v2/validation/VALIDATION_5542.jpg
#   inflating: validation_v2/validation/VALIDATION_5543.jpg
#   inflating: validation_v2/validation/VALIDATION_5544.jpg
#   inflating: validation_v2/validation/VALIDATION_5545.jpg
#   inflating: validation_v2/validation/VALIDATION_5546.jpg
#   inflating: validation_v2/validation/VALIDATION_5547.jpg
#   inflating: validation_v2/validation/VALIDATION_5548.jpg
#   inflating: validation_v2/validation/VALIDATION_5549.jpg
#   inflating: validation_v2/validation/VALIDATION_5550.jpg
#   inflating: validation_v2/validation/VALIDATION_5551.jpg
#   inflating: validation_v2/validation/VALIDATION_5552.jpg
#   inflating: validation_v2/validation/VALIDATION_5553.jpg
#   inflating: validation_v2/validation/VALIDATION_5554.jpg
#   inflating: validation_v2/validation/VALIDATION_5555.jpg
#   inflating: validation_v2/validation/VALIDATION_5556.jpg
#   inflating: validation_v2/validation/VALIDATION_5557.jpg
#   inflating: validation_v2/validation/VALIDATION_5558.jpg
#   inflating: validation_v2/validation/VALIDATION_5559.jpg
#   inflating: validation_v2/validation/VALIDATION_5560.jpg
#   inflating: validation_v2/validation/VALIDATION_5561.jpg
#   inflating: validation_v2/validation/VALIDATION_5562.jpg
#   inflating: validation_v2/validation/VALIDATION_5563.jpg
#   inflating: validation_v2/validation/VALIDATION_5564.jpg
#   inflating: validation_v2/validation/VALIDATION_5565.jpg
#   inflating: validation_v2/validation/VALIDATION_5566.jpg
#   inflating: validation_v2/validation/VALIDATION_5567.jpg
#   inflating: validation_v2/validation/VALIDATION_5568.jpg
#   inflating: validation_v2/validation/VALIDATION_5569.jpg
#   inflating: validation_v2/validation/VALIDATION_5570.jpg
#   inflating: validation_v2/validation/VALIDATION_5571.jpg
#   inflating: validation_v2/validation/VALIDATION_5572.jpg
#   inflating: validation_v2/validation/VALIDATION_5573.jpg
#   inflating: validation_v2/validation/VALIDATION_5574.jpg
#   inflating: validation_v2/validation/VALIDATION_5575.jpg
#   inflating: validation_v2/validation/VALIDATION_5576.jpg
#   inflating: validation_v2/validation/VALIDATION_5577.jpg
#   inflating: validation_v2/validation/VALIDATION_5578.jpg
#   inflating: validation_v2/validation/VALIDATION_5579.jpg
#   inflating: validation_v2/validation/VALIDATION_5580.jpg
#   inflating: validation_v2/validation/VALIDATION_5581.jpg
#   inflating: validation_v2/validation/VALIDATION_5582.jpg
#   inflating: validation_v2/validation/VALIDATION_5583.jpg
#   inflating: validation_v2/validation/VALIDATION_5584.jpg
#   inflating: validation_v2/validation/VALIDATION_5585.jpg
#   inflating: validation_v2/validation/VALIDATION_5586.jpg
#   inflating: validation_v2/validation/VALIDATION_5587.jpg
#   inflating: validation_v2/validation/VALIDATION_5588.jpg
#   inflating: validation_v2/validation/VALIDATION_5589.jpg
#   inflating: validation_v2/validation/VALIDATION_5590.jpg
#   inflating: validation_v2/validation/VALIDATION_5591.jpg
#   inflating: validation_v2/validation/VALIDATION_5592.jpg
#   inflating: validation_v2/validation/VALIDATION_5593.jpg
#   inflating: validation_v2/validation/VALIDATION_5594.jpg
#   inflating: validation_v2/validation/VALIDATION_5595.jpg
#   inflating: validation_v2/validation/VALIDATION_5596.jpg
#   inflating: validation_v2/validation/VALIDATION_5597.jpg
#   inflating: validation_v2/validation/VALIDATION_5598.jpg
#   inflating: validation_v2/validation/VALIDATION_5599.jpg
#   inflating: validation_v2/validation/VALIDATION_5600.jpg
#   inflating: validation_v2/validation/VALIDATION_5601.jpg
#   inflating: validation_v2/validation/VALIDATION_5602.jpg
#   inflating: validation_v2/validation/VALIDATION_5603.jpg
#   inflating: validation_v2/validation/VALIDATION_5604.jpg
#   inflating: validation_v2/validation/VALIDATION_5605.jpg
#   inflating: validation_v2/validation/VALIDATION_5606.jpg
#   inflating: validation_v2/validation/VALIDATION_5607.jpg
#   inflating: validation_v2/validation/VALIDATION_5608.jpg
#   inflating: validation_v2/validation/VALIDATION_5609.jpg
#   inflating: validation_v2/validation/VALIDATION_5610.jpg
#   inflating: validation_v2/validation/VALIDATION_5611.jpg
#   inflating: validation_v2/validation/VALIDATION_5612.jpg
#   inflating: validation_v2/validation/VALIDATION_5613.jpg
#   inflating: validation_v2/validation/VALIDATION_5614.jpg
#   inflating: validation_v2/validation/VALIDATION_5615.jpg
#   inflating: validation_v2/validation/VALIDATION_5616.jpg
#   inflating: validation_v2/validation/VALIDATION_5617.jpg
#   inflating: validation_v2/validation/VALIDATION_5618.jpg
#   inflating: validation_v2/validation/VALIDATION_5619.jpg
#   inflating: validation_v2/validation/VALIDATION_5620.jpg
#   inflating: validation_v2/validation/VALIDATION_5621.jpg
#   inflating: validation_v2/validation/VALIDATION_5622.jpg
#   inflating: validation_v2/validation/VALIDATION_5623.jpg
#   inflating: validation_v2/validation/VALIDATION_5624.jpg
#   inflating: validation_v2/validation/VALIDATION_5625.jpg
#   inflating: validation_v2/validation/VALIDATION_5626.jpg
#   inflating: validation_v2/validation/VALIDATION_5627.jpg
#   inflating: validation_v2/validation/VALIDATION_5628.jpg
#   inflating: validation_v2/validation/VALIDATION_5629.jpg
#   inflating: validation_v2/validation/VALIDATION_5630.jpg
#   inflating: validation_v2/validation/VALIDATION_5631.jpg
#   inflating: validation_v2/validation/VALIDATION_5632.jpg
#   inflating: validation_v2/validation/VALIDATION_5633.jpg
#   inflating: validation_v2/validation/VALIDATION_5634.jpg
#   inflating: validation_v2/validation/VALIDATION_5635.jpg
#   inflating: validation_v2/validation/VALIDATION_5636.jpg
#   inflating: validation_v2/validation/VALIDATION_5637.jpg
#   inflating: validation_v2/validation/VALIDATION_5638.jpg
#   inflating: validation_v2/validation/VALIDATION_5639.jpg
#   inflating: validation_v2/validation/VALIDATION_5640.jpg
#   inflating: validation_v2/validation/VALIDATION_5641.jpg
#   inflating: validation_v2/validation/VALIDATION_5642.jpg
#   inflating: validation_v2/validation/VALIDATION_5643.jpg
#   inflating: validation_v2/validation/VALIDATION_5644.jpg
#   inflating: validation_v2/validation/VALIDATION_5645.jpg
#   inflating: validation_v2/validation/VALIDATION_5646.jpg
#   inflating: validation_v2/validation/VALIDATION_5647.jpg
#   inflating: validation_v2/validation/VALIDATION_5648.jpg
#   inflating: validation_v2/validation/VALIDATION_5649.jpg
#   inflating: validation_v2/validation/VALIDATION_5650.jpg
#   inflating: validation_v2/validation/VALIDATION_5651.jpg
#   inflating: validation_v2/validation/VALIDATION_5652.jpg
#   inflating: validation_v2/validation/VALIDATION_5653.jpg
#   inflating: validation_v2/validation/VALIDATION_5654.jpg
#   inflating: validation_v2/validation/VALIDATION_5655.jpg
#   inflating: validation_v2/validation/VALIDATION_5656.jpg
#   inflating: validation_v2/validation/VALIDATION_5657.jpg
#   inflating: validation_v2/validation/VALIDATION_5658.jpg
#   inflating: validation_v2/validation/VALIDATION_5659.jpg
#   inflating: validation_v2/validation/VALIDATION_5660.jpg
#   inflating: validation_v2/validation/VALIDATION_5661.jpg
#   inflating: validation_v2/validation/VALIDATION_5662.jpg
#   inflating: validation_v2/validation/VALIDATION_5663.jpg
#   inflating: validation_v2/validation/VALIDATION_5664.jpg
#   inflating: validation_v2/validation/VALIDATION_5665.jpg
#   inflating: validation_v2/validation/VALIDATION_5666.jpg
#   inflating: validation_v2/validation/VALIDATION_5667.jpg
#   inflating: validation_v2/validation/VALIDATION_5668.jpg
#   inflating: validation_v2/validation/VALIDATION_5669.jpg
#   inflating: validation_v2/validation/VALIDATION_5670.jpg
#   inflating: validation_v2/validation/VALIDATION_5671.jpg
#   inflating: validation_v2/validation/VALIDATION_5672.jpg
#   inflating: validation_v2/validation/VALIDATION_5673.jpg
#   inflating: validation_v2/validation/VALIDATION_5674.jpg
#   inflating: validation_v2/validation/VALIDATION_5675.jpg
#   inflating: validation_v2/validation/VALIDATION_5676.jpg
#   inflating: validation_v2/validation/VALIDATION_5677.jpg
#   inflating: validation_v2/validation/VALIDATION_5678.jpg
#   inflating: validation_v2/validation/VALIDATION_5679.jpg
#   inflating: validation_v2/validation/VALIDATION_5680.jpg
#   inflating: validation_v2/validation/VALIDATION_5681.jpg
#   inflating: validation_v2/validation/VALIDATION_5682.jpg
#   inflating: validation_v2/validation/VALIDATION_5683.jpg
#   inflating: validation_v2/validation/VALIDATION_5684.jpg
#   inflating: validation_v2/validation/VALIDATION_5685.jpg
#   inflating: validation_v2/validation/VALIDATION_5686.jpg
#   inflating: validation_v2/validation/VALIDATION_5687.jpg
#   inflating: validation_v2/validation/VALIDATION_5688.jpg
#   inflating: validation_v2/validation/VALIDATION_5689.jpg
#   inflating: validation_v2/validation/VALIDATION_5690.jpg
#   inflating: validation_v2/validation/VALIDATION_5691.jpg
#   inflating: validation_v2/validation/VALIDATION_5692.jpg
#   inflating: validation_v2/validation/VALIDATION_5693.jpg
#   inflating: validation_v2/validation/VALIDATION_5694.jpg
#   inflating: validation_v2/validation/VALIDATION_5695.jpg
#   inflating: validation_v2/validation/VALIDATION_5696.jpg
#   inflating: validation_v2/validation/VALIDATION_5697.jpg
#   inflating: validation_v2/validation/VALIDATION_5698.jpg
#   inflating: validation_v2/validation/VALIDATION_5699.jpg
#   inflating: validation_v2/validation/VALIDATION_5700.jpg
#   inflating: validation_v2/validation/VALIDATION_5701.jpg
#   inflating: validation_v2/validation/VALIDATION_5702.jpg
#   inflating: validation_v2/validation/VALIDATION_5703.jpg
#   inflating: validation_v2/validation/VALIDATION_5704.jpg
#   inflating: validation_v2/validation/VALIDATION_5705.jpg
#   inflating: validation_v2/validation/VALIDATION_5706.jpg
#   inflating: validation_v2/validation/VALIDATION_5707.jpg
#   inflating: validation_v2/validation/VALIDATION_5708.jpg
#   inflating: validation_v2/validation/VALIDATION_5709.jpg
#   inflating: validation_v2/validation/VALIDATION_5710.jpg
#   inflating: validation_v2/validation/VALIDATION_5711.jpg
#   inflating: validation_v2/validation/VALIDATION_5712.jpg
#   inflating: validation_v2/validation/VALIDATION_5713.jpg
#   inflating: validation_v2/validation/VALIDATION_5714.jpg
#   inflating: validation_v2/validation/VALIDATION_5715.jpg
#   inflating: validation_v2/validation/VALIDATION_5716.jpg
#   inflating: validation_v2/validation/VALIDATION_5717.jpg
#   inflating: validation_v2/validation/VALIDATION_5718.jpg
#   inflating: validation_v2/validation/VALIDATION_5719.jpg
#   inflating: validation_v2/validation/VALIDATION_5720.jpg
#   inflating: validation_v2/validation/VALIDATION_5721.jpg
#   inflating: validation_v2/validation/VALIDATION_5722.jpg
#   inflating: validation_v2/validation/VALIDATION_5723.jpg
#   inflating: validation_v2/validation/VALIDATION_5724.jpg
#   inflating: validation_v2/validation/VALIDATION_5725.jpg
#   inflating: validation_v2/validation/VALIDATION_5726.jpg
#   inflating: validation_v2/validation/VALIDATION_5727.jpg
#   inflating: validation_v2/validation/VALIDATION_5728.jpg
#   inflating: validation_v2/validation/VALIDATION_5729.jpg
#   inflating: validation_v2/validation/VALIDATION_5730.jpg
#   inflating: validation_v2/validation/VALIDATION_5731.jpg
#   inflating: validation_v2/validation/VALIDATION_5732.jpg
#   inflating: validation_v2/validation/VALIDATION_5733.jpg
#   inflating: validation_v2/validation/VALIDATION_5734.jpg
#   inflating: validation_v2/validation/VALIDATION_5735.jpg
#   inflating: validation_v2/validation/VALIDATION_5736.jpg
#   inflating: validation_v2/validation/VALIDATION_5737.jpg
#   inflating: validation_v2/validation/VALIDATION_5738.jpg
#   inflating: validation_v2/validation/VALIDATION_5739.jpg
#   inflating: validation_v2/validation/VALIDATION_5740.jpg
#   inflating: validation_v2/validation/VALIDATION_5741.jpg
#   inflating: validation_v2/validation/VALIDATION_5742.jpg
#   inflating: validation_v2/validation/VALIDATION_5743.jpg
#   inflating: validation_v2/validation/VALIDATION_5744.jpg
#   inflating: validation_v2/validation/VALIDATION_5745.jpg
#   inflating: validation_v2/validation/VALIDATION_5746.jpg
#   inflating: validation_v2/validation/VALIDATION_5747.jpg
#   inflating: validation_v2/validation/VALIDATION_5748.jpg
#   inflating: validation_v2/validation/VALIDATION_5749.jpg
#   inflating: validation_v2/validation/VALIDATION_5750.jpg
#   inflating: validation_v2/validation/VALIDATION_5751.jpg
#   inflating: validation_v2/validation/VALIDATION_5752.jpg
#   inflating: validation_v2/validation/VALIDATION_5753.jpg
#   inflating: validation_v2/validation/VALIDATION_5754.jpg
#   inflating: validation_v2/validation/VALIDATION_5755.jpg
#   inflating: validation_v2/validation/VALIDATION_5756.jpg
#   inflating: validation_v2/validation/VALIDATION_5757.jpg
#   inflating: validation_v2/validation/VALIDATION_5758.jpg
#   inflating: validation_v2/validation/VALIDATION_5759.jpg
#   inflating: validation_v2/validation/VALIDATION_5760.jpg
#   inflating: validation_v2/validation/VALIDATION_5761.jpg
#   inflating: validation_v2/validation/VALIDATION_5762.jpg
#   inflating: validation_v2/validation/VALIDATION_5763.jpg
#   inflating: validation_v2/validation/VALIDATION_5764.jpg
#   inflating: validation_v2/validation/VALIDATION_5765.jpg
#   inflating: validation_v2/validation/VALIDATION_5766.jpg
#   inflating: validation_v2/validation/VALIDATION_5767.jpg
#   inflating: validation_v2/validation/VALIDATION_5768.jpg
#   inflating: validation_v2/validation/VALIDATION_5769.jpg
#   inflating: validation_v2/validation/VALIDATION_5770.jpg
#   inflating: validation_v2/validation/VALIDATION_5771.jpg
#   inflating: validation_v2/validation/VALIDATION_5772.jpg
#   inflating: validation_v2/validation/VALIDATION_5773.jpg
#   inflating: validation_v2/validation/VALIDATION_5774.jpg
#   inflating: validation_v2/validation/VALIDATION_5775.jpg
#   inflating: validation_v2/validation/VALIDATION_5776.jpg
#   inflating: validation_v2/validation/VALIDATION_5777.jpg
#   inflating: validation_v2/validation/VALIDATION_5778.jpg
#   inflating: validation_v2/validation/VALIDATION_5779.jpg
#   inflating: validation_v2/validation/VALIDATION_5780.jpg
#   inflating: validation_v2/validation/VALIDATION_5781.jpg
#   inflating: validation_v2/validation/VALIDATION_5782.jpg
#   inflating: validation_v2/validation/VALIDATION_5783.jpg
#   inflating: validation_v2/validation/VALIDATION_5784.jpg
#   inflating: validation_v2/validation/VALIDATION_5785.jpg
#   inflating: validation_v2/validation/VALIDATION_5786.jpg
#   inflating: validation_v2/validation/VALIDATION_5787.jpg
#   inflating: validation_v2/validation/VALIDATION_5788.jpg
#   inflating: validation_v2/validation/VALIDATION_5789.jpg
#   inflating: validation_v2/validation/VALIDATION_5790.jpg
#   inflating: validation_v2/validation/VALIDATION_5791.jpg
#   inflating: validation_v2/validation/VALIDATION_5792.jpg
#   inflating: validation_v2/validation/VALIDATION_5793.jpg
#   inflating: validation_v2/validation/VALIDATION_5794.jpg
#   inflating: validation_v2/validation/VALIDATION_5795.jpg
#   inflating: validation_v2/validation/VALIDATION_5796.jpg
#   inflating: validation_v2/validation/VALIDATION_5797.jpg
#   inflating: validation_v2/validation/VALIDATION_5798.jpg
#   inflating: validation_v2/validation/VALIDATION_5799.jpg
#   inflating: validation_v2/validation/VALIDATION_5800.jpg
#   inflating: validation_v2/validation/VALIDATION_5801.jpg
# ...
#   inflating: validation_v2/validation/VALIDATION_9736.jpg
#   inflating: validation_v2/validation/VALIDATION_9737.jpg
#   inflating: validation_v2/validation/VALIDATION_9738.jpg
#   inflating: validation_v2/validation/VALIDATION_9739.jpg
#   inflating: validation_v2/validation/VALIDATION_9740.jpg
#   inflating: validation_v2/validation/VALIDATION_9741.jpg
#   inflating: validation_v2/validation/VALIDATION_9742.jpg
#   inflating: validation_v2/validation/VALIDATION_9743.jpg
#   inflating: validation_v2/validation/VALIDATION_9744.jpg
#   inflating: validation_v2/validation/VALIDATION_9745.jpg
#   inflating: validation_v2/validation/VALIDATION_9746.jpg
#   inflating: validation_v2/validation/VALIDATION_9747.jpg
#   inflating: validation_v2/validation/VALIDATION_9748.jpg
#   inflating: validation_v2/validation/VALIDATION_9749.jpg
#   inflating: validation_v2/validation/VALIDATION_9750.jpg
#   inflating: validation_v2/validation/VALIDATION_9751.jpg
#   inflating: validation_v2/validation/VALIDATION_9752.jpg
#   inflating: validation_v2/validation/VALIDATION_9753.jpg
#   inflating: validation_v2/validation/VALIDATION_9754.jpg
#   inflating: validation_v2/validation/VALIDATION_9755.jpg
#   inflating: validation_v2/validation/VALIDATION_9756.jpg
#   inflating: validation_v2/validation/VALIDATION_9757.jpg
#   inflating: validation_v2/validation/VALIDATION_9758.jpg
#   inflating: validation_v2/validation/VALIDATION_9759.jpg
#   inflating: validation_v2/validation/VALIDATION_9760.jpg
#   inflating: validation_v2/validation/VALIDATION_9761.jpg
#   inflating: validation_v2/validation/VALIDATION_9762.jpg
#   inflating: validation_v2/validation/VALIDATION_9763.jpg
#   inflating: validation_v2/validation/VALIDATION_9764.jpg
#   inflating: validation_v2/validation/VALIDATION_9765.jpg
#   inflating: validation_v2/validation/VALIDATION_9766.jpg
#   inflating: validation_v2/validation/VALIDATION_9767.jpg
#   inflating: validation_v2/validation/VALIDATION_9768.jpg
#   inflating: validation_v2/validation/VALIDATION_9769.jpg
#   inflating: validation_v2/validation/VALIDATION_9770.jpg
#   inflating: validation_v2/validation/VALIDATION_9771.jpg
#   inflating: validation_v2/validation/VALIDATION_9772.jpg
#   inflating: validation_v2/validation/VALIDATION_9773.jpg
#   inflating: validation_v2/validation/VALIDATION_9774.jpg
#   inflating: validation_v2/validation/VALIDATION_9775.jpg
#   inflating: validation_v2/validation/VALIDATION_9776.jpg
#   inflating: validation_v2/validation/VALIDATION_9777.jpg
#   inflating: validation_v2/validation/VALIDATION_9778.jpg
#   inflating: validation_v2/validation/VALIDATION_9779.jpg
#   inflating: validation_v2/validation/VALIDATION_9780.jpg
#   inflating: validation_v2/validation/VALIDATION_9781.jpg
#   inflating: validation_v2/validation/VALIDATION_9782.jpg
#   inflating: validation_v2/validation/VALIDATION_9783.jpg
#   inflating: validation_v2/validation/VALIDATION_9784.jpg
#   inflating: validation_v2/validation/VALIDATION_9785.jpg
#   inflating: validation_v2/validation/VALIDATION_9786.jpg
#   inflating: validation_v2/validation/VALIDATION_9787.jpg
#   inflating: validation_v2/validation/VALIDATION_9788.jpg
#   inflating: validation_v2/validation/VALIDATION_9789.jpg
#   inflating: validation_v2/validation/VALIDATION_9790.jpg
#   inflating: validation_v2/validation/VALIDATION_9791.jpg
#   inflating: validation_v2/validation/VALIDATION_9792.jpg
#   inflating: validation_v2/validation/VALIDATION_9793.jpg
#   inflating: validation_v2/validation/VALIDATION_9794.jpg
#   inflating: validation_v2/validation/VALIDATION_9795.jpg
#   inflating: validation_v2/validation/VALIDATION_9796.jpg
#   inflating: validation_v2/validation/VALIDATION_9797.jpg
#   inflating: validation_v2/validation/VALIDATION_9798.jpg
#   inflating: validation_v2/validation/VALIDATION_9799.jpg
#   inflating: validation_v2/validation/VALIDATION_9800.jpg
#   inflating: validation_v2/validation/VALIDATION_9801.jpg
#   inflating: validation_v2/validation/VALIDATION_9802.jpg
#   inflating: validation_v2/validation/VALIDATION_9803.jpg
#   inflating: validation_v2/validation/VALIDATION_9804.jpg
#   inflating: validation_v2/validation/VALIDATION_9805.jpg
#   inflating: validation_v2/validation/VALIDATION_9806.jpg
#   inflating: validation_v2/validation/VALIDATION_9807.jpg
#   inflating: validation_v2/validation/VALIDATION_9808.jpg
#   inflating: validation_v2/validation/VALIDATION_9809.jpg
#   inflating: validation_v2/validation/VALIDATION_9810.jpg
#   inflating: validation_v2/validation/VALIDATION_9811.jpg
#   inflating: validation_v2/validation/VALIDATION_9812.jpg
#   inflating: validation_v2/validation/VALIDATION_9813.jpg
#   inflating: validation_v2/validation/VALIDATION_9814.jpg
#   inflating: validation_v2/validation/VALIDATION_9815.jpg
#   inflating: validation_v2/validation/VALIDATION_9816.jpg
#   inflating: validation_v2/validation/VALIDATION_9817.jpg
#   inflating: validation_v2/validation/VALIDATION_9818.jpg
#   inflating: validation_v2/validation/VALIDATION_9819.jpg
#   inflating: validation_v2/validation/VALIDATION_9820.jpg
#   inflating: validation_v2/validation/VALIDATION_9821.jpg
#   inflating: validation_v2/validation/VALIDATION_9822.jpg
#   inflating: validation_v2/validation/VALIDATION_9823.jpg
#   inflating: validation_v2/validation/VALIDATION_9824.jpg
#   inflating: validation_v2/validation/VALIDATION_9825.jpg
#   inflating: validation_v2/validation/VALIDATION_9826.jpg
#   inflating: validation_v2/validation/VALIDATION_9827.jpg
#   inflating: validation_v2/validation/VALIDATION_9828.jpg
#   inflating: validation_v2/validation/VALIDATION_9829.jpg
#   inflating: validation_v2/validation/VALIDATION_9830.jpg
#   inflating: validation_v2/validation/VALIDATION_9831.jpg
#   inflating: validation_v2/validation/VALIDATION_9832.jpg
#   inflating: validation_v2/validation/VALIDATION_9833.jpg
#   inflating: validation_v2/validation/VALIDATION_9834.jpg
#   inflating: validation_v2/validation/VALIDATION_9835.jpg
#   inflating: validation_v2/validation/VALIDATION_9836.jpg
#   inflating: validation_v2/validation/VALIDATION_9837.jpg
#   inflating: validation_v2/validation/VALIDATION_9838.jpg
#   inflating: validation_v2/validation/VALIDATION_9839.jpg
#   inflating: validation_v2/validation/VALIDATION_9840.jpg
#   inflating: validation_v2/validation/VALIDATION_9841.jpg
#   inflating: validation_v2/validation/VALIDATION_9842.jpg
#   inflating: validation_v2/validation/VALIDATION_9843.jpg
#   inflating: validation_v2/validation/VALIDATION_9844.jpg
#   inflating: validation_v2/validation/VALIDATION_9845.jpg
#   inflating: validation_v2/validation/VALIDATION_9846.jpg
#   inflating: validation_v2/validation/VALIDATION_9847.jpg
#   inflating: validation_v2/validation/VALIDATION_9848.jpg
#   inflating: validation_v2/validation/VALIDATION_9849.jpg
#   inflating: validation_v2/validation/VALIDATION_9850.jpg
#   inflating: validation_v2/validation/VALIDATION_9851.jpg
#   inflating: validation_v2/validation/VALIDATION_9852.jpg
#   inflating: validation_v2/validation/VALIDATION_9853.jpg
#   inflating: validation_v2/validation/VALIDATION_9854.jpg
#   inflating: validation_v2/validation/VALIDATION_9855.jpg
#   inflating: validation_v2/validation/VALIDATION_9856.jpg
#   inflating: validation_v2/validation/VALIDATION_9857.jpg
#   inflating: validation_v2/validation/VALIDATION_9858.jpg
#   inflating: validation_v2/validation/VALIDATION_9859.jpg
#   inflating: validation_v2/validation/VALIDATION_9860.jpg
#   inflating: validation_v2/validation/VALIDATION_9861.jpg
#   inflating: validation_v2/validation/VALIDATION_9862.jpg
#   inflating: validation_v2/validation/VALIDATION_9863.jpg
#   inflating: validation_v2/validation/VALIDATION_9864.jpg
#   inflating: validation_v2/validation/VALIDATION_9865.jpg
#   inflating: validation_v2/validation/VALIDATION_9866.jpg
#   inflating: validation_v2/validation/VALIDATION_9867.jpg
#   inflating: validation_v2/validation/VALIDATION_9868.jpg
#   inflating: validation_v2/validation/VALIDATION_9869.jpg
#   inflating: validation_v2/validation/VALIDATION_9870.jpg
#   inflating: validation_v2/validation/VALIDATION_9871.jpg
#   inflating: validation_v2/validation/VALIDATION_9872.jpg
#   inflating: validation_v2/validation/VALIDATION_9873.jpg
#   inflating: validation_v2/validation/VALIDATION_9874.jpg
#   inflating: validation_v2/validation/VALIDATION_9875.jpg
#   inflating: validation_v2/validation/VALIDATION_9876.jpg
#   inflating: validation_v2/validation/VALIDATION_9877.jpg
#   inflating: validation_v2/validation/VALIDATION_9878.jpg
#   inflating: validation_v2/validation/VALIDATION_9879.jpg
#   inflating: validation_v2/validation/VALIDATION_9880.jpg
#   inflating: validation_v2/validation/VALIDATION_9881.jpg
#   inflating: validation_v2/validation/VALIDATION_9882.jpg
#   inflating: validation_v2/validation/VALIDATION_9883.jpg
#   inflating: validation_v2/validation/VALIDATION_9884.jpg
#   inflating: validation_v2/validation/VALIDATION_9885.jpg
#   inflating: validation_v2/validation/VALIDATION_9886.jpg
#   inflating: validation_v2/validation/VALIDATION_9887.jpg
#   inflating: validation_v2/validation/VALIDATION_9888.jpg
#   inflating: validation_v2/validation/VALIDATION_9889.jpg
#   inflating: validation_v2/validation/VALIDATION_9890.jpg
#   inflating: validation_v2/validation/VALIDATION_9891.jpg
#   inflating: validation_v2/validation/VALIDATION_9892.jpg
#   inflating: validation_v2/validation/VALIDATION_9893.jpg
#   inflating: validation_v2/validation/VALIDATION_9894.jpg
#   inflating: validation_v2/validation/VALIDATION_9895.jpg
#   inflating: validation_v2/validation/VALIDATION_9896.jpg
#   inflating: validation_v2/validation/VALIDATION_9897.jpg
#   inflating: validation_v2/validation/VALIDATION_9898.jpg
#   inflating: validation_v2/validation/VALIDATION_9899.jpg
#   inflating: validation_v2/validation/VALIDATION_9900.jpg
#   inflating: validation_v2/validation/VALIDATION_9901.jpg
#   inflating: validation_v2/validation/VALIDATION_9902.jpg
#   inflating: validation_v2/validation/VALIDATION_9903.jpg
#   inflating: validation_v2/validation/VALIDATION_9904.jpg
#   inflating: validation_v2/validation/VALIDATION_9905.jpg
#   inflating: validation_v2/validation/VALIDATION_9906.jpg
#   inflating: validation_v2/validation/VALIDATION_9907.jpg
#   inflating: validation_v2/validation/VALIDATION_9908.jpg
#   inflating: validation_v2/validation/VALIDATION_9909.jpg
#   inflating: validation_v2/validation/VALIDATION_9910.jpg
#   inflating: validation_v2/validation/VALIDATION_9911.jpg
#   inflating: validation_v2/validation/VALIDATION_9912.jpg
#   inflating: validation_v2/validation/VALIDATION_9913.jpg
#   inflating: validation_v2/validation/VALIDATION_9914.jpg
#   inflating: validation_v2/validation/VALIDATION_9915.jpg
#   inflating: validation_v2/validation/VALIDATION_9916.jpg
#   inflating: validation_v2/validation/VALIDATION_9917.jpg
#   inflating: validation_v2/validation/VALIDATION_9918.jpg
#   inflating: validation_v2/validation/VALIDATION_9919.jpg
#   inflating: validation_v2/validation/VALIDATION_9920.jpg
#   inflating: validation_v2/validation/VALIDATION_9921.jpg
#   inflating: validation_v2/validation/VALIDATION_9922.jpg
#   inflating: validation_v2/validation/VALIDATION_9923.jpg
#   inflating: validation_v2/validation/VALIDATION_9924.jpg
#   inflating: validation_v2/validation/VALIDATION_9925.jpg
#   inflating: validation_v2/validation/VALIDATION_9926.jpg
#   inflating: validation_v2/validation/VALIDATION_9927.jpg
#   inflating: validation_v2/validation/VALIDATION_9928.jpg
#   inflating: validation_v2/validation/VALIDATION_9929.jpg
#   inflating: validation_v2/validation/VALIDATION_9930.jpg
#   inflating: validation_v2/validation/VALIDATION_9931.jpg
#   inflating: validation_v2/validation/VALIDATION_9932.jpg
#   inflating: validation_v2/validation/VALIDATION_9933.jpg
#   inflating: validation_v2/validation/VALIDATION_9934.jpg
#   inflating: validation_v2/validation/VALIDATION_9935.jpg
#   inflating: validation_v2/validation/VALIDATION_9936.jpg
#   inflating: validation_v2/validation/VALIDATION_9937.jpg
#   inflating: validation_v2/validation/VALIDATION_9938.jpg
#   inflating: validation_v2/validation/VALIDATION_9939.jpg
#   inflating: validation_v2/validation/VALIDATION_9940.jpg
#   inflating: validation_v2/validation/VALIDATION_9941.jpg
#   inflating: validation_v2/validation/VALIDATION_9942.jpg
#   inflating: validation_v2/validation/VALIDATION_9943.jpg
#   inflating: validation_v2/validation/VALIDATION_9944.jpg
#   inflating: validation_v2/validation/VALIDATION_9945.jpg
#   inflating: validation_v2/validation/VALIDATION_9946.jpg
#   inflating: validation_v2/validation/VALIDATION_9947.jpg
#   inflating: validation_v2/validation/VALIDATION_9948.jpg
#   inflating: validation_v2/validation/VALIDATION_9949.jpg
#   inflating: validation_v2/validation/VALIDATION_9950.jpg
#   inflating: validation_v2/validation/VALIDATION_9951.jpg
#   inflating: validation_v2/validation/VALIDATION_9952.jpg
#   inflating: validation_v2/validation/VALIDATION_9953.jpg
#   inflating: validation_v2/validation/VALIDATION_9954.jpg
#   inflating: validation_v2/validation/VALIDATION_9955.jpg
#   inflating: validation_v2/validation/VALIDATION_9956.jpg
#   inflating: validation_v2/validation/VALIDATION_9957.jpg
#   inflating: validation_v2/validation/VALIDATION_9958.jpg
#   inflating: validation_v2/validation/VALIDATION_9959.jpg
#   inflating: validation_v2/validation/VALIDATION_9960.jpg
#   inflating: validation_v2/validation/VALIDATION_9961.jpg
#   inflating: validation_v2/validation/VALIDATION_9962.jpg
#   inflating: validation_v2/validation/VALIDATION_9963.jpg
#   inflating: validation_v2/validation/VALIDATION_9964.jpg
#   inflating: validation_v2/validation/VALIDATION_9965.jpg
#   inflating: validation_v2/validation/VALIDATION_9966.jpg
#   inflating: validation_v2/validation/VALIDATION_9967.jpg
#   inflating: validation_v2/validation/VALIDATION_9968.jpg
#   inflating: validation_v2/validation/VALIDATION_9969.jpg
#   inflating: validation_v2/validation/VALIDATION_9970.jpg
#   inflating: validation_v2/validation/VALIDATION_9971.jpg
#   inflating: validation_v2/validation/VALIDATION_9972.jpg
#   inflating: validation_v2/validation/VALIDATION_9973.jpg
#   inflating: validation_v2/validation/VALIDATION_9974.jpg
#   inflating: validation_v2/validation/VALIDATION_9975.jpg
#   inflating: validation_v2/validation/VALIDATION_9976.jpg
#   inflating: validation_v2/validation/VALIDATION_9977.jpg
#   inflating: validation_v2/validation/VALIDATION_9978.jpg
#   inflating: validation_v2/validation/VALIDATION_9979.jpg
#   inflating: validation_v2/validation/VALIDATION_9980.jpg
#   inflating: validation_v2/validation/VALIDATION_9981.jpg
#   inflating: validation_v2/validation/VALIDATION_9982.jpg
#   inflating: validation_v2/validation/VALIDATION_9983.jpg
#   inflating: validation_v2/validation/VALIDATION_9984.jpg
#   inflating: validation_v2/validation/VALIDATION_9985.jpg
#   inflating: validation_v2/validation/VALIDATION_9986.jpg
#   inflating: validation_v2/validation/VALIDATION_9987.jpg
#   inflating: validation_v2/validation/VALIDATION_9988.jpg
#   inflating: validation_v2/validation/VALIDATION_9989.jpg
#   inflating: validation_v2/validation/VALIDATION_9990.jpg
#   inflating: validation_v2/validation/VALIDATION_9991.jpg
#   inflating: validation_v2/validation/VALIDATION_9992.jpg
#   inflating: validation_v2/validation/VALIDATION_9993.jpg
#   inflating: validation_v2/validation/VALIDATION_9994.jpg
#   inflating: validation_v2/validation/VALIDATION_9995.jpg
#   inflating: validation_v2/validation/VALIDATION_9996.jpg
#   inflating: validation_v2/validation/VALIDATION_9997.jpg
#   inflating: validation_v2/validation/VALIDATION_9998.jpg
#   inflating: validation_v2/validation/VALIDATION_9999.jpg
#   inflating: written_name_test_v2.csv
#   inflating: written_name_train_v2.csv
#   inflating: written_name_validation_v2.csv

# %% [markdown]
# # Import the libraries

# %%
import torch
import tensorflow as tf
import os
import cv2
import imghdr
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelBinarizer
from itertools import chain
import random
import shutil
from sklearn.model_selection import train_test_split
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from torchvision import transforms, datasets
import torch.nn.functional as F
import torchvision.transforms.functional as TF
from tqdm import tqdm

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Clean the data

# %%
train = pd.read_csv('written_name_train_v2.csv')
validation = pd.read_csv('written_name_validation_v2.csv')

# %%
print("Number of NaNs in train set      : ", train['IDENTITY'].isnull().sum())
print("Number of NaNs in validation set : ", validation['IDENTITY'].isnull().sum())
# Out:
# Number of NaNs in train set      :  565
# Number of NaNs in validation set :  78

# %%
train.dropna(axis=0, inplace=True)
validation.dropna(axis=0, inplace=True)

# %%
train_data = train[train['IDENTITY'] != 'UNREADABLE']
valid_data = validation[validation['IDENTITY'] != 'UNREADABLE']

# %%
train_data['IDENTITY'] = train_data['IDENTITY'].str.upper()
valid_data['IDENTITY'] = valid_data['IDENTITY'].str.upper()
# Out:
# <ipython-input-8-8fe6abeeb9f2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['IDENTITY'] = train_data['IDENTITY'].str.upper()
# <ipython-input-8-8fe6abeeb9f2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_data['IDENTITY'] = valid_data['IDENTITY'].str.upper()

# %%
train_data.reset_index(inplace = True, drop=True)
valid_data.reset_index(inplace = True, drop=True)

# %% [markdown]
# # Initiate Data Loader

# %%
class DataGenerator(Dataset):
    def __init__(self, dataframe, path, char_map, transform=None):
        self.dataframe = dataframe
        self.path = path
        self.char_map = char_map
        # self.img_size = img_size
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_path = self.dataframe['FILENAME'].values[idx]
        img = cv2.imread(os.path.join(self.path, img_path), cv2.IMREAD_GRAYSCALE)
        # img = cv2.resize(img, self.img_size)
        img = img / 255.0
        if self.transform:
            img = self.transform(img)
        img = torch.tensor(img, dtype=torch.float32).unsqueeze(0)

        text = str(self.dataframe['IDENTITY'].values[idx])
        label = torch.tensor([self.char_map[char] for char in text], dtype=torch.long)
        return img, label

# %%
characters = sorted(set("".join(train['IDENTITY'].astype(str)).upper()))
char_to_label = {char: idx for idx, char in enumerate(characters)}
label_to_char = {idx: char for char, idx in char_to_label.items()}

print(char_to_label)
# Out:
# {' ': 0, "'": 1, '-': 2, 'A': 3, 'B': 4, 'C': 5, 'D': 6, 'E': 7, 'F': 8, 'G': 9, 'H': 10, 'I': 11, 'J': 12, 'K': 13, 'L': 14, 'M': 15, 'N': 16, 'O': 17, 'P': 18, 'Q': 19, 'R': 20, 'S': 21, 'T': 22, 'U': 23, 'V': 24, 'W': 25, 'X': 26, 'Y': 27, 'Z': 28, '`': 29}

# %%
transform = transforms.Compose([
    transforms.ToTensor()
])

# %%
path_train = "train_v2/train/"
path_valid = "validation_v2/validation/"

# %%
train_dataset = DataGenerator(train_data,path_train,char_to_label)
valid_dataset = DataGenerator(valid_data,path_valid,char_to_label)

# %%
train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=1, shuffle=False)

# %%
for i, (images, labels) in enumerate(train_loader):
    print(f"Batch {i}:")
    print(images.shape)  # This will give you the shape of the batch of images
    print(labels.shape)  # And this will give you the shape of the batch of labels
    break  # Just to demonstrate, stop after the first batch
# Out:
# Batch 0:
# torch.Size([1, 1, 36, 388])
# torch.Size([1, 5])

# %% [markdown]
# # Segment the images

# %%
def segment_words(image_tensor, label):
    """
    Given an image tensor and a label tensor, this function extracts letters from the image
    and returns a list of segmented letter images.

    Parameters
    ----------
    image_tensor : PyTorch tensor of the image to classify
    label : PyTorch tensor representing the word as a sequence of character numbers

    Returns
    -------
    list of numpy arrays: Each array represents a segmented letter image.
    """

    segmented_letters = []

    # Convert the image tensor to a NumPy array
    image = image_tensor.squeeze().numpy()
    image = (image * 255).astype('uint8')  # Assuming the tensor is normalized [0, 1]

    # Convert the image to grayscale if it's not already
    if image.ndim == 3:
        gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    else:
        gray = image

    # Apply threshold to binarize the image
    _, thresh = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Sort contours from left to right
    contours = sorted(contours, key=lambda ctr: cv2.boundingRect(ctr)[0])

    # Convert the label tensor to a list of integers
    label_list = label.flatten().tolist()


    # Check if the number of contours matches the length of the label
    if len(contours) == len(label_list):
        # Iterate over the contours and extract each letter as a separate image
        for i, contour in enumerate(contours):
            # Get the bounding box of the contour
            x, y, w, h = cv2.boundingRect(contour)

            # Extract the letter
            letter_img = image[y:y+h, x:x+w]
            # letter_tensor = torch.tensor(letter_img, dtype=torch.float32)
            segmented_letters.append(letter_img)

    return segmented_letters

# %%
def resize_and_filter(segmented_letters, target_size=(10, 14)):
    """
    Resize segmented letter images to the target size while maintaining aspect ratio.
    Parameters
    ----------
    segmented_letters : list of PyTorch tensors
        Each tensor represents a segmented letter image.
    target_size : tuple, optional
        Target size for resizing the segmented letter images. Default is (10, 14).
    Returns
    -------
    list of PyTorch tensors: Each tensor represents a resized segmented letter image.
    """
    resized_letters = []

    for letter_img in segmented_letters:
        # Get the dimensions of the image
        height, width = letter_img.shape

        # Calculate the aspect ratio
        aspect_ratio = width / height

        # Determine new dimensions maintaining the aspect ratio
        if aspect_ratio > 1:  # Width is greater than height
            new_width = min(target_size[1], int(target_size[0] * aspect_ratio))
            new_height = min(target_size[0], int(new_width / aspect_ratio))
        else:  # Height is greater than or equal to width
            new_height = min(target_size[0], int(target_size[1] / aspect_ratio))
            new_width = min(target_size[1], int(new_height * aspect_ratio))

        # Ensure new_width and new_height are positive
        new_width = max(1, new_width)
        new_height = max(1, new_height)

        # Resize the image to new dimensions
        resized_img = cv2.resize(letter_img, (new_width, new_height), interpolation=cv2.INTER_AREA)

        # Make dark pixels black
        _, thresholded_img = cv2.threshold(resized_img, 175, 255, cv2.THRESH_BINARY)

        # Create a blank white image of target size
        new_img = np.ones((target_size[0], target_size[1]), dtype=np.uint8) * 255

        # Calculate the offset to paste the resized image
        x_offset = (target_size[1] - new_width) // 2
        y_offset = (target_size[0] - new_height) // 2

        # Paste the resized image onto the blank white image
        new_img[y_offset:y_offset + new_height, x_offset:x_offset + new_width] = thresholded_img

        # Convert the cropped image back to a PyTorch tensor
        resized_tensor = torch.tensor(new_img, dtype=torch.float32)

        resized_letters.append(resized_tensor)

    return resized_letters

# %%
for images, labels in train_loader:
    letters = segment_words(images, labels)
    if len(letters) == 0:
        continue
    else:
        break
letters = resize_and_filter(letters)
print(letters!=0)
# Out:
# True

# %%
num_letters = len(letters)

if num_letters == 0:
    print("No letters to display.")


for i, letter_img in enumerate(letters):

    plt.figure(figsize=(2, 2))
    plt.imshow(letter_img, cmap='gray')
    plt.title(f'Letter {i+1}')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # Load the pre-trained CNN model

# %%
# Define SimpleCNN model
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        """
        Entren imatges amb 1 canal de color (grayscale) i amb aquesta capa convolucional
        s'estreuen característiques loclas de la imatge detectant patrons com bordes,
        textures i altres detalls que poden ser importants.
        """
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        """
        El max pooling redueix la dimensionalitat dels mapas de característiques,
        disminuint la mida de les imatges i retenint les característiques més importants
        Això ajuda a reduir el sobreajustament i millora l'eficàcia computacional.
        """
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

        self.dropout = nn.Dropout(0.5)
        """
        Les següents dues capes s'ecarreguen de la classificació final. Transformen
        les característiques extretes per les capas convolucionals i de pooling a les
        propietats de les diferents classes (lletres).
        """
        self.fc1 = nn.Linear(16 * 7 * 5, 64)
        self.fc2 = nn.Linear(64, 29)  # 29 perquè hi ha 29 caràcters a l'alfabet

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = x.view(-1, 16 * 7 * 5)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# Load your trained CNN model
cnn_model = SimpleCNN()
cnn_model.load_state_dict(torch.load('simple_cnn_model.pth'))
cnn_model.eval()
# Out:
# SimpleCNN(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=560, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=29, bias=True)
# )

# %% [markdown]
# # Create SimpleLSTM model

# %%
# Define SimpleLSTM model
class SimpleLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(SimpleLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h_0 = torch.zeros(num_layers, x.size(0), hidden_size).to(x.device)
        c_0 = torch.zeros(num_layers, x.size(0), hidden_size).to(x.device)
        out, _ = self.lstm(x, (h_0, c_0))
        out = self.fc(out[:, -1, :])
        return out

# %%
# LSTM model parameters
input_size = 29  # This should match the CNN output size
hidden_size = 64
num_layers = 1
output_size = 29  # Number of classes
lstm_model = SimpleLSTM(input_size, hidden_size, num_layers, output_size)

# %% [markdown]
# # Train the model

# %%
# Define loss and optimizer for LSTM
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(lstm_model.parameters(), lr=0.0005)

# %%
# Define constants
batch = 1
num_epochs = 10
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []

# %%
for epoch in range(num_epochs):
    # Training
    lstm_model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in tqdm(train_loader, desc="Processing images"):
        optimizer.zero_grad()

        for i, l in zip(images, labels):
            # Segment images
            segmented_images = resize_and_filter(segment_words(i, l))

            if len(segmented_images) == 0:
                continue

            segmented_images_tensor = torch.stack(segmented_images)



            # Reshape the tensor with a batch size of 1
            #[batch_size, 1, embedding]
            segmented_images_tensor = segmented_images_tensor.view(segmented_images_tensor.size(0), 1, segmented_images_tensor.size(1), segmented_images_tensor.size(2))


            # CNN feature extraction
            with torch.no_grad():
                features = cnn_model(segmented_images_tensor)

            # Reshape features for LSTM
            features = features.view(-1, 1, features.size(1))

            # RNN
            outputs = lstm_model(features)

            loss = criterion(outputs, l.view(-1))
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += l.size(0)
            correct += (predicted == l.view(-1)).sum().item()

    epoch_loss = running_loss / len(train_loader)
    epoch_accuracy = correct / total
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)

    # Validation
    lstm_model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in valid_loader:
          for i, l in zip(images, labels):
            segmented_images = resize_and_filter(segment_words(i, l))

            if len(segmented_images) == 0:
                continue

            segmented_images_tensor = torch.stack(segmented_images)

            segmented_images = segmented_images_tensor.view(segmented_images_tensor.size(0), 1, segmented_images_tensor.size(1), segmented_images_tensor.size(2))

            with torch.no_grad():
                features = cnn_model(segmented_images)

            features = features.view(-1, 1, features.size(1))
            outputs = lstm_model(features)
            loss = criterion(outputs, l.view(-1))

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += l.size(0)
            correct += (predicted == l.view(-1)).sum().item()

    epoch_loss = running_loss / len(valid_loader)
    epoch_accuracy = correct / total
    test_losses.append(epoch_loss)
    test_accuracies.append(epoch_accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}, \nTrain Loss: {train_losses[-1]:.4f}, Train Acc: {train_accuracies[-1]:.4f}, \n Test Loss: {test_losses[-1]:.4f},  Test Acc: {test_accuracies[-1]:.4f}\n")

# Save the trained model
torch.save(lstm_model.state_dict(), 'cnn_rnn_model.pth')
# Out:
# Processing images: 100%|██████████| 330294/330294 [08:02<00:00, 684.61it/s]
# Epoch 1/10,
# Train Loss: 0.1233, Train Acc: 0.7381,
#  Test Loss: 0.1111,  Test Acc: 0.7666
# Processing images: 100%|██████████| 330294/330294 [07:32<00:00, 730.04it/s]
# Epoch 2/10,
# Train Loss: 0.1061, Train Acc: 0.7718,
#  Test Loss: 0.1076,  Test Acc: 0.7747
# Processing images: 100%|██████████| 330294/330294 [07:37<00:00, 722.19it/s]
# Epoch 3/10,
# Train Loss: 0.1024, Train Acc: 0.7799,
#  Test Loss: 0.1040,  Test Acc: 0.7799
# Processing images: 100%|██████████| 330294/330294 [07:41<00:00, 715.13it/s]
# Epoch 4/10,
# Train Loss: 0.0988, Train Acc: 0.7887,
#  Test Loss: 0.1019,  Test Acc: 0.7878
# Processing images: 100%|██████████| 330294/330294 [07:30<00:00, 733.21it/s]
# Epoch 5/10,
# Train Loss: 0.0965, Train Acc: 0.7933,
#  Test Loss: 0.0999,  Test Acc: 0.7907
# Processing images: 100%|██████████| 330294/330294 [07:38<00:00, 719.97it/s]
# Epoch 6/10,
# Train Loss: 0.0949, Train Acc: 0.7969,
#  Test Loss: 0.0973,  Test Acc: 0.7950
# Processing images: 100%|██████████| 330294/330294 [07:36<00:00, 722.90it/s]
# Epoch 7/10,
# Train Loss: 0.0936, Train Acc: 0.7996,
#  Test Loss: 0.0975,  Test Acc: 0.7968
# Processing images: 100%|██████████| 330294/330294 [07:41<00:00, 714.95it/s]
# Epoch 8/10,
# Train Loss: 0.0945, Train Acc: 0.7984,
#  Test Loss: 0.0988,  Test Acc: 0.7945
# Processing images: 100%|██████████| 330294/330294 [07:37<00:00, 722.21it/s]
# Epoch 9/10,
# Train Loss: 0.0930, Train Acc: 0.8015,
#  Test Loss: 0.0956,  Test Acc: 0.8009
# Processing images: 100%|██████████| 330294/330294 [07:28<00:00, 735.77it/s]
# Epoch 10/10,
# Train Loss: 0.0922, Train Acc: 0.8026,
#  Test Loss: 0.0954,  Test Acc: 0.8020

# %%
# Create loss and accuracy plots
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs+1), train_losses, label='Training Loss')
plt.plot(range(1, num_epochs+1), test_losses, label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs+1), train_accuracies, label='Training Accuracy')
plt.plot(range(1, num_epochs+1), test_accuracies, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Over Epochs')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
